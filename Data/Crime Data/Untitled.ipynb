# %%
import pandas as pd
import numpy as np
import requests
import time
import csv
import json

json_df = pd.read_json('test_output.json')
json_df
# Out:
#                           DESCRIPTION                       LAT_LONG  \
# 0                      FELONY ASSAULT  [40.756266207, -73.990501248]
# 1                       GRAND LARCENY  [40.756043535, -73.986949544]
# 2                       PETIT LARCENY  [40.749118855, -73.990141355]
# 3                       GRAND LARCENY  [40.756642042, -73.988371577]
# 4                       HARRASSMENT 2   [40.757317199, -73.98788056]
# 5                      FELONY ASSAULT  [40.754171029, -73.982503147]
# 6                       GRAND LARCENY  [40.757034305, -73.986238271]
# 7                       GRAND LARCENY  [40.751449824, -73.976050545]
# 8      CRIMINAL MISCHIEF & RELATED OF  [40.744902089, -73.983010825]
# 9            VEHICLE AND TRAFFIC LAWS  [40.756225283, -73.994244301]
# 10                      GRAND LARCENY  [40.747919222, -73.988243174]
# 11       ASSAULT 3 & RELATED OFFENSES  [40.752903782, -73.989245685]
# 12                      PETIT LARCENY  [40.759139936, -73.990266211]
# ...
