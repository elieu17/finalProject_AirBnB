# %%
#Import dependencies
import pandas as pd
import numpy as np
import csv
import json
from pprint import pprint

json_df = pd.read_json('Crime2018.json')
json_df
# Out:
#         ADDR_PCT_CD        BORO_NM  KY_CD   LAW_CAT_CD  \
# 0                14      MANHATTAN    109       FELONY
# 1                73       BROOKLYN    344  MISDEMEANOR
# 2                67       BROOKLYN    351  MISDEMEANOR
# 3                 5      MANHATTAN    344  MISDEMEANOR
# 4                46          BRONX    344  MISDEMEANOR
# 5                52          BRONX    348  MISDEMEANOR
# 6                26      MANHATTAN    105       FELONY
# 7                43          BRONX    351  MISDEMEANOR
# 8                49          BRONX    348  MISDEMEANOR
# 9               113         QUEENS    578    VIOLATION
# 10              104         QUEENS    106       FELONY
# 11              104         QUEENS    359  MISDEMEANOR
# 12              115         QUEENS    348  MISDEMEANOR
# 13              122  STATEN ISLAND    347  MISDEMEANOR
# 14               63       BROOKLYN    106       FELONY
# 15              110         QUEENS    578    VIOLATION
# ...

# %%
json_df.to_csv("2017_CrimeData.csv", sep=',')
