# %%
import requests

# %%
Key = '06e95084cb5d3426c57b51987827eb7d'
url = "https://developers.zomato.com/api/v2.1/"

headers= {
    "user-key":Key,
    "Accept": "application/json" 
}
params= {
    "category": 3,
    "entity_id": 280,
    "entity_type": "city",
}

# search
results = requests.get(url=url+"search?",headers=headers,params=params)

# %%
results.json()
# Out:
# {'results_found': 2469,
#  'results_start': 0,
#  'results_shown': 20,
#  'restaurants': [{'restaurant': {'R': {'res_id': 16761344},
#     'apikey': '06e95084cb5d3426c57b51987827eb7d',
#     'id': '16761344',
#     'name': 'Buddakan',
#     'url': 'https://www.zomato.com/new-york-city/buddakan-greenwich-village?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#     'location': {'address': '75 9th Avenue 10011',
#      'locality': '9th Avenue, Greenwich Village',
#      'city': 'New York City',
#      'city_id': 280,
#      'latitude': '40.7422762672',
#      'longitude': '-74.0048000962',
#      'zipcode': '10011',
#      'country_id': 216,
#      'locality_verbose': '9th Avenue, Greenwich Village, New York City'},
#     'switch_to_order_menu': 0,
#     'cuisines': 'Chinese, Fusion, Asian',
#     'average_cost_for_two': 130,
#     'price_range': 4,
#     'currency': '$',
#     'offers': [],
#     'opentable_support': 0,
#     'is_zomato_book_res': 0,
#     'mezzo_provider': 'OTHER',
#     'is_book_form_web_view': 0,
#     'book_form_web_view_url': '',
#     'book_again_url': '',
#     'thumb': 'https://b.zmtcdn.com/data/pictures/4/16761344/5535198640b49778b948e916d392ebb8.jpg?fit=around%7C200%3A200&crop=200%3A200%3B%2A%2C%2A',
#     'user_rating': {'aggregate_rating': '4.9',
#      'rating_text': 'Excellent',
#      'rating_color': '3F7E00',
#      'votes': '906',
#      'has_fake_reviews': 0},
#     'photos_url': 'https://www.zomato.com/new-york-city/buddakan-greenwich-village/photos?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1#tabtop',
#     'menu_url': 'https://www.zomato.com/new-york-city/buddakan-greenwich-village/menu?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1&openSwipeBox=menu&showMinimal=1#tabtop',
#     'featured_image': 'https://b.zmtcdn.com/data/pictures/4/16761344/5535198640b49778b948e916d392ebb8.jpg',
#     'has_online_delivery': 0,
#     'is_delivering_now': 0,
#     'has_fake_reviews': 0,
#     'include_bogo_offers': True,
#     'deeplink': 'zomato://restaurant/16761344',
#     'is_table_reservation_supported': 0,
#     'has_table_booking': 0,
#     'events_url': 'https://www.zomato.com/new-york-city/buddakan-greenwich-village/events#tabtop?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#     'establishment_types': []}},
#   {'restaurant': {'R': {'res_id': 16761868},
#     'apikey': '06e95084cb5d3426c57b51987827eb7d',
#     'id': '16761868',
#     'name': 'Cafeteria',
#     'url': 'https://www.zomato.com/new-york-city/cafeteria-chelsea-manhattan?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#     'location': {'address': '119 7th Avenue 10011',
#      'locality': 'Chelsea, Manhattan',
#      'city': 'New York City',
#      'city_id': 280,
#      'latitude': '40.7407100000',
#      'longitude': '-73.9980000000',
#      'zipcode': '10011',
#      'country_id': 216,
#      'locality_verbose': 'Chelsea, Manhattan'},
#     'switch_to_order_menu': 0,
#     'cuisines': 'American',
#     'average_cost_for_two': 75,
#     'price_range': 4,
#     'currency': '$',
#     'offers': [],
#     'opentable_support': 0,
#     'is_zomato_book_res': 0,
#     'mezzo_provider': 'OTHER',
#     'is_book_form_web_view': 0,
#     'book_form_web_view_url': '',
#     'book_again_url': '',
#     'thumb': 'https://b.zmtcdn.com/data/pictures/chains/8/16761868/bd779e8a55d1e38bf489a4b373099cf1.jpg?fit=around%7C200%3A200&crop=200%3A200%3B%2A%2C%2A',
#     'user_rating': {'aggregate_rating': '4.4',
#      'rating_text': 'Very Good',
#      'rating_color': '5BA829',
#      'votes': '634',
#      'has_fake_reviews': 0},
#     'photos_url': 'https://www.zomato.com/new-york-city/cafeteria-chelsea-manhattan/photos?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1#tabtop',
#     'menu_url': 'https://www.zomato.com/new-york-city/cafeteria-chelsea-manhattan/menu?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1&openSwipeBox=menu&showMinimal=1#tabtop',
#     'featured_image': 'https://b.zmtcdn.com/data/pictures/chains/8/16761868/bd779e8a55d1e38bf489a4b373099cf1.jpg',
#     'has_online_delivery': 0,
#     'is_delivering_now': 0,
#     'has_fake_reviews': 0,
#     'include_bogo_offers': True,
#     'deeplink': 'zomato://restaurant/16761868',
#     'is_table_reservation_supported': 0,
#     'has_table_booking': 0,
#     'events_url': 'https://www.zomato.com/new-york-city/cafeteria-chelsea-manhattan/events#tabtop?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#     'establishment_types': []}},
#   {'restaurant': {'R': {'res_id': 16777961},
#     'apikey': '06e95084cb5d3426c57b51987827eb7d',
#     'id': '16777961',
#     'name': 'The Spotted Pig',
#     'url': 'https://www.zomato.com/new-york-city/the-spotted-pig-greenwich-village?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#     'location': {'address': '314 West 11th Street 10014',
#      'locality': 'Greenwich Village',
#      'city': 'New York City',
#      'city_id': 280,
#      'latitude': '40.7355900000',
#      'longitude': '-74.0065000000',
#      'zipcode': '10014',
#      'country_id': 216,
#      'locality_verbose': 'Greenwich Village'},
#     'switch_to_order_menu': 0,
#     'cuisines': 'Burger, Bar Food',
#     'average_cost_for_two': 70,
#     'price_range': 4,
#     'currency': '$',
#     'offers': [],
#     'opentable_support': 0,
#     'is_zomato_book_res': 0,
#     'mezzo_provider': 'OTHER',
#     'is_book_form_web_view': 0,
#     'book_form_web_view_url': '',
#     'book_again_url': '',
#     'thumb': 'https://b.zmtcdn.com/data/pictures/chains/1/16777961/1c02d5846ed641b4a9d096b1486f30e2.png?fit=around%7C200%3A200&crop=200%3A200%3B%2A%2C%2A',
#     'user_rating': {'aggregate_rating': '4.7',
#      'rating_text': 'Excellent',
#      'rating_color': '3F7E00',
#      'votes': '1272',
#      'has_fake_reviews': 0},
#     'photos_url': 'https://www.zomato.com/new-york-city/the-spotted-pig-greenwich-village/photos?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1#tabtop',
#     'menu_url': 'https://www.zomato.com/new-york-city/the-spotted-pig-greenwich-village/menu?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1&openSwipeBox=menu&showMinimal=1#tabtop',
#     'featured_image': 'https://b.zmtcdn.com/data/pictures/chains/1/16777961/1c02d5846ed641b4a9d096b1486f30e2.png',
#     'has_online_delivery': 0,
#     'is_delivering_now': 0,
#     'has_fake_reviews': 0,
#     'include_bogo_offers': True,
#     'deeplink': 'zomato://restaurant/16777961',
#     'is_table_reservation_supported': 0,
#     'has_table_booking': 0,
#     'events_url': 'https://www.zomato.com/new-york-city/the-spotted-pig-greenwich-village/events#tabtop?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#     'establishment_types': []}},
#   {'restaurant': {'R': {'res_id': 16761333},
#     'apikey': '06e95084cb5d3426c57b51987827eb7d',
#     'id': '16761333',
#     'name': 'Bubba Gump Shrimp Co.',
#     'url': 'https://www.zomato.com/new-york-city/bubba-gump-shrimp-co-gramercy?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#     'location': {'address': '1501 Broadway 10036',
#      'locality': 'Gramercy',
#      'city': 'New York City',
#      'city_id': 280,
#      'latitude': '40.7571940000',
#      'longitude': '-73.9864036000',
#      'zipcode': '10036',
#      'country_id': 216,
#      'locality_verbose': 'Gramercy'},
#     'switch_to_order_menu': 0,
#     'cuisines': 'Seafood, Cajun',
#     'average_cost_for_two': 55,
#     'price_range': 3,
#     'currency': '$',
#     'offers': [],
#     'opentable_support': 0,
#     'is_zomato_book_res': 0,
#     'mezzo_provider': 'OTHER',
#     'is_book_form_web_view': 0,
#     'book_form_web_view_url': '',
#     'book_again_url': '',
#     'thumb': 'https://b.zmtcdn.com/data/pictures/3/16761333/de635ffc678174b1b0ca7c43458a0844.jpg?fit=around%7C200%3A200&crop=200%3A200%3B%2A%2C%2A',
#     'user_rating': {'aggregate_rating': '4.4',
#      'rating_text': 'Very Good',
#      'rating_color': '5BA829',
#      'votes': '291',
#      'has_fake_reviews': 0},
#     'photos_url': 'https://www.zomato.com/new-york-city/bubba-gump-shrimp-co-gramercy/photos?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1#tabtop',
#     'menu_url': 'https://www.zomato.com/new-york-city/bubba-gump-shrimp-co-gramercy/menu?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1&openSwipeBox=menu&showMinimal=1#tabtop',
#     'featured_image': 'https://b.zmtcdn.com/data/pictures/3/16761333/de635ffc678174b1b0ca7c43458a0844.jpg',
#     'has_online_delivery': 0,
#     'is_delivering_now': 0,
#     'has_fake_reviews': 0,
#     'include_bogo_offers': True,
#     'deeplink': 'zomato://restaurant/16761333',
#     'is_table_reservation_supported': 0,
#     'has_table_booking': 0,
#     'events_url': 'https://www.zomato.com/new-york-city/bubba-gump-shrimp-co-gramercy/events#tabtop?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#     'establishment_types': []}},
#   {'restaurant': {'R': {'res_id': 16760892},
#     'apikey': '06e95084cb5d3426c57b51987827eb7d',
#     'id': '16760892',
#     'name': 'Blue Ribbon Brasserie',
#     'url': 'https://www.zomato.com/new-york-city/blue-ribbon-brasserie-greenwich-village?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#     'location': {'address': '97 Sullivan Street, New York 10012',
#      'locality': 'Sullivan Street, Greenwich Village',
#      'city': 'New York City',
#      'city_id': 280,
#      'latitude': '40.7255250000',
#      'longitude': '-74.0031444444',
#      'zipcode': '10012',
#      'country_id': 216,
#      'locality_verbose': 'Sullivan Street, Greenwich Village, New York City'},
#     'switch_to_order_menu': 0,
#     'cuisines': 'European, Seafood',
#     'average_cost_for_two': 120,
#     'price_range': 4,
#     'currency': '$',
#     'offers': [],
#     'opentable_support': 0,
#     'is_zomato_book_res': 0,
#     'mezzo_provider': 'OTHER',
#     'is_book_form_web_view': 0,
#     'book_form_web_view_url': '',
#     'book_again_url': '',
#     'thumb': 'https://b.zmtcdn.com/data/pictures/chains/2/16760892/f669f4162eb51b9237fce8e30a67034d.jpg?fit=around%7C200%3A200&crop=200%3A200%3B%2A%2C%2A',
#     'user_rating': {'aggregate_rating': '4.4',
#      'rating_text': 'Very Good',
#      'rating_color': '5BA829',
#      'votes': '462',
#      'has_fake_reviews': 0},
#     'photos_url': 'https://www.zomato.com/new-york-city/blue-ribbon-brasserie-greenwich-village/photos?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1#tabtop',
#     'menu_url': 'https://www.zomato.com/new-york-city/blue-ribbon-brasserie-greenwich-village/menu?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1&openSwipeBox=menu&showMinimal=1#tabtop',
#     'featured_image': 'https://b.zmtcdn.com/data/pictures/chains/2/16760892/f669f4162eb51b9237fce8e30a67034d.jpg?output-format=webp',
#     'has_online_delivery': 0,
#     'is_delivering_now': 0,
#     'has_fake_reviews': 0,
#     'include_bogo_offers': True,
#     'deeplink': 'zomato://restaurant/16760892',
#     'is_table_reservation_supported': 0,
#     'has_table_booking': 0,
#     'events_url': 'https://www.zomato.com/new-york-city/blue-ribbon-brasserie-greenwich-village/events#tabtop?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#     'establishment_types': []}},
#   {'restaurant': {'R': {'res_id': 16781905},
#     'apikey': '06e95084cb5d3426c57b51987827eb7d',
#     'id': '16781905',
#     'name': 'Ayza Wine & Chocolate Bar',
#     'url': 'https://www.zomato.com/new-york-city/ayza-wine-chocolate-bar-gramercy?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#     'location': {'address': '11 West 31st Street, New York 10016',
#      'locality': 'West 31st Street, Gramercy',
#      'city': 'New York City',
#      'city_id': 280,
#      'latitude': '40.7470083333',
#      'longitude': '-73.9870388889',
#      'zipcode': '10016',
#      'country_id': 216,
#      'locality_verbose': 'West 31st Street, Gramercy, New York City'},
#     'switch_to_order_menu': 0,
#     'cuisines': 'Mediterranean, Desserts, Bar Food',
#     'average_cost_for_two': 100,
#     'price_range': 4,
#     'currency': '$',
#     'offers': [],
#     'opentable_support': 0,
#     'is_zomato_book_res': 0,
#     'mezzo_provider': 'OTHER',
#     'is_book_form_web_view': 0,
#     'book_form_web_view_url': '',
#     'book_again_url': '',
#     'thumb': 'https://b.zmtcdn.com/data/res_imagery/16781905_RESTAURANT_b22a0c0989f40210efb601e49508180c_c.png?fit=around%7C200%3A200&crop=200%3A200%3B%2A%2C%2A',
#     'user_rating': {'aggregate_rating': '4.4',
#      'rating_text': 'Very Good',
#      'rating_color': '5BA829',
#      'votes': '471',
#      'has_fake_reviews': 0},
#     'photos_url': 'https://www.zomato.com/new-york-city/ayza-wine-chocolate-bar-gramercy/photos?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1#tabtop',
#     'menu_url': 'https://www.zomato.com/new-york-city/ayza-wine-chocolate-bar-gramercy/menu?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1&openSwipeBox=menu&showMinimal=1#tabtop',
#     'featured_image': 'https://b.zmtcdn.com/data/res_imagery/16781905_RESTAURANT_b22a0c0989f40210efb601e49508180c_c.png',
#     'has_online_delivery': 0,
#     'is_delivering_now': 0,
#     'has_fake_reviews': 0,
#     'include_bogo_offers': True,
#     'deeplink': 'zomato://restaurant/16781905',
#     'is_table_reservation_supported': 0,
#     'has_table_booking': 0,
#     'events_url': 'https://www.zomato.com/new-york-city/ayza-wine-chocolate-bar-gramercy/events#tabtop?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#     'establishment_types': []}},
#   {'restaurant': {'R': {'res_id': 16780256},
#     'apikey': '06e95084cb5d3426c57b51987827eb7d',
#     'id': '16780256',
#     'name': 'Union Square Cafe',
#     'url': 'https://www.zomato.com/new-york-city/union-square-cafe-gramercy-flatiron?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#     'location': {'address': '16th Street, New York 10003',
#      'locality': 'East 16th Street, Gramercy-Flatiron',
#      'city': 'New York City',
#      'city_id': 280,
#      'latitude': '40.7369333333',
#      'longitude': '-73.9913472222',
#      'zipcode': '10003',
#      'country_id': 216,
#      'locality_verbose': 'East 16th Street, Gramercy-Flatiron, New York City'},
#     'switch_to_order_menu': 0,
#     'cuisines': 'American, Italian',
#     'average_cost_for_two': 75,
#     'price_range': 4,
#     'currency': '$',
#     'offers': [],
#     'opentable_support': 0,
#     'is_zomato_book_res': 0,
#     'mezzo_provider': 'OTHER',
#     'is_book_form_web_view': 0,
#     'book_form_web_view_url': '',
#     'book_again_url': '',
#     'thumb': '',
#     'user_rating': {'aggregate_rating': '4.4',
#      'rating_text': 'Very Good',
#      'rating_color': '5BA829',
#      'votes': '496',
#      'has_fake_reviews': 0},
#     'photos_url': 'https://www.zomato.com/new-york-city/union-square-cafe-gramercy-flatiron/photos?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1#tabtop',
#     'menu_url': 'https://www.zomato.com/new-york-city/union-square-cafe-gramercy-flatiron/menu?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1&openSwipeBox=menu&showMinimal=1#tabtop',
#     'featured_image': '',
#     'has_online_delivery': 0,
#     'is_delivering_now': 0,
#     'has_fake_reviews': 0,
#     'include_bogo_offers': True,
#     'deeplink': 'zomato://restaurant/16780256',
#     'is_table_reservation_supported': 0,
#     'has_table_booking': 0,
#     'events_url': 'https://www.zomato.com/new-york-city/union-square-cafe-gramercy-flatiron/events#tabtop?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#     'establishment_types': []}},
#   {'restaurant': {'R': {'res_id': 16785930},
#     'apikey': '06e95084cb5d3426c57b51987827eb7d',
#     'id': '16785930',
#     'name': 'Beauty & Essex',
#     'url': 'https://www.zomato.com/new-york-city/beauty-essex-lower-east-side?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#     'location': {'address': '146 Essex Street, Lower East Side 10002',
#      'locality': 'Lower East Side',
#      'city': 'New York City',
#      'city_id': 280,
#      'latitude': '40.7205111111',
#      'longitude': '-73.9871444444',
#      'zipcode': '10002',
#      'country_id': 216,
#      'locality_verbose': 'Lower East Side'},
#     'switch_to_order_menu': 0,
#     'cuisines': 'American, Fusion',
#     'average_cost_for_two': 100,
#     'price_range': 4,
#     'currency': '$',
#     'offers': [],
#     'opentable_support': 0,
#     'is_zomato_book_res': 0,
#     'mezzo_provider': 'OTHER',
#     'is_book_form_web_view': 0,
#     'book_form_web_view_url': '',
#     'book_again_url': '',
#     'thumb': 'https://b.zmtcdn.com/data/pictures/0/16785930/24251ba0b3352b5165a7c8ac7f2d9169.jpg?fit=around%7C200%3A200&crop=200%3A200%3B%2A%2C%2A',
#     'user_rating': {'aggregate_rating': '4.3',
#      'rating_text': 'Very Good',
#      'rating_color': '5BA829',
#      'votes': '204',
#      'has_fake_reviews': 0},
#     'photos_url': 'https://www.zomato.com/new-york-city/beauty-essex-lower-east-side/photos?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1#tabtop',
#     'menu_url': 'https://www.zomato.com/new-york-city/beauty-essex-lower-east-side/menu?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1&openSwipeBox=menu&showMinimal=1#tabtop',
#     'featured_image': 'https://b.zmtcdn.com/data/pictures/0/16785930/24251ba0b3352b5165a7c8ac7f2d9169.jpg?output-format=webp',
#     'has_online_delivery': 0,
#     'is_delivering_now': 0,
#     'has_fake_reviews': 0,
#     'include_bogo_offers': True,
#     'deeplink': 'zomato://restaurant/16785930',
#     'is_table_reservation_supported': 0,
#     'has_table_booking': 0,
#     'events_url': 'https://www.zomato.com/new-york-city/beauty-essex-lower-east-side/events#tabtop?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#     'establishment_types': []}},
#   {'restaurant': {'R': {'res_id': 16778036},
#     'apikey': '06e95084cb5d3426c57b51987827eb7d',
#     'id': '16778036',
#     'name': 'Stanton Social',
#     'url': 'https://www.zomato.com/new-york-city/stanton-social-lower-east-side?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#     'location': {'address': '99 Stanton Street, New York 10002',
#      'locality': 'Lower East Side',
#      'city': 'New York City',
#      'city_id': 280,
#      'latitude': '40.7211940000',
#      'longitude': '-73.9881470000',
#      'zipcode': '10002',
#      'country_id': 216,
#      'locality_verbose': 'Lower East Side'},
#     'switch_to_order_menu': 0,
#     'cuisines': 'New American, International',
#     'average_cost_for_two': 120,
#     'price_range': 4,
#     'currency': '$',
#     'offers': [],
#     'opentable_support': 0,
#     'is_zomato_book_res': 0,
#     'mezzo_provider': 'OTHER',
#     'is_book_form_web_view': 0,
#     'book_form_web_view_url': '',
#     'book_again_url': '',
#     'thumb': 'https://b.zmtcdn.com/data/res_imagery/16778036_RESTAURANT_0b29a42455284a0deb6e3e69283a47d3.jpg?fit=around%7C200%3A200&crop=200%3A200%3B%2A%2C%2A',
#     'user_rating': {'aggregate_rating': '4.4',
#      'rating_text': 'Very Good',
#      'rating_color': '5BA829',
#      'votes': '311',
#      'has_fake_reviews': 0},
#     'photos_url': 'https://www.zomato.com/new-york-city/stanton-social-lower-east-side/photos?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1#tabtop',
#     'menu_url': 'https://www.zomato.com/new-york-city/stanton-social-lower-east-side/menu?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1&openSwipeBox=menu&showMinimal=1#tabtop',
#     'featured_image': 'https://b.zmtcdn.com/data/res_imagery/16778036_RESTAURANT_0b29a42455284a0deb6e3e69283a47d3.jpg',
#     'has_online_delivery': 0,
#     'is_delivering_now': 0,
#     'has_fake_reviews': 0,
#     'include_bogo_offers': True,
#     'deeplink': 'zomato://restaurant/16778036',
#     'is_table_reservation_supported': 0,
#     'has_table_booking': 0,
#     'events_url': 'https://www.zomato.com/new-york-city/stanton-social-lower-east-side/events#tabtop?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#     'establishment_types': []}},
#   {'restaurant': {'R': {'res_id': 16776568},
#     'apikey': '06e95084cb5d3426c57b51987827eb7d',
#     'id': '16776568',
#     'name': 'Rosa Mexicano',
#     'url': 'https://www.zomato.com/new-york-city/rosa-mexicano-gramercy-flatiron?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#     'location': {'address': '9 East 18th Street 10003',
#      'locality': 'Gramercy-Flatiron',
#      'city': 'New York City',
#      'city_id': 280,
#      'latitude': '40.7383400000',
#      'longitude': '-73.9911900000',
#      'zipcode': '10003',
#      'country_id': 216,
#      'locality_verbose': 'Gramercy-Flatiron'},
#     'switch_to_order_menu': 0,
#     'cuisines': 'Mexican',
#     'average_cost_for_two': 90,
#     'price_range': 4,
#     'currency': '$',
#     'offers': [],
#     'opentable_support': 0,
#     'is_zomato_book_res': 0,
#     'mezzo_provider': 'OTHER',
#     'is_book_form_web_view': 0,
#     'book_form_web_view_url': '',
#     'book_again_url': '',
#     'thumb': 'https://b.zmtcdn.com/data/res_imagery/16776568_RESTAURANT_fc12f90a8ca44aebab986634401b4052_c.jpg?fit=around%7C200%3A200&crop=200%3A200%3B%2A%2C%2A',
#     'user_rating': {'aggregate_rating': '4.1',
#      'rating_text': 'Very Good',
#      'rating_color': '5BA829',
#      'votes': '205',
#      'has_fake_reviews': 0},
#     'photos_url': 'https://www.zomato.com/new-york-city/rosa-mexicano-gramercy-flatiron/photos?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1#tabtop',
#     'menu_url': 'https://www.zomato.com/new-york-city/rosa-mexicano-gramercy-flatiron/menu?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1&openSwipeBox=menu&showMinimal=1#tabtop',
#     'featured_image': 'https://b.zmtcdn.com/data/res_imagery/16776568_RESTAURANT_fc12f90a8ca44aebab986634401b4052_c.jpg',
#     'has_online_delivery': 0,
#     'is_delivering_now': 0,
#     'has_fake_reviews': 0,
#     'include_bogo_offers': True,
#     'deeplink': 'zomato://restaurant/16776568',
#     'is_table_reservation_supported': 0,
#     'has_table_booking': 0,
#     'events_url': 'https://www.zomato.com/new-york-city/rosa-mexicano-gramercy-flatiron/events#tabtop?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#     'establishment_types': []}},
#   {'restaurant': {'R': {'res_id': 16774083},
#     'apikey': '06e95084cb5d3426c57b51987827eb7d',
#     'id': '16774083',
#     'name': 'Old Homestead Steakhouse',
#     'url': 'https://www.zomato.com/new-york-city/old-homestead-steakhouse-greenwich-village?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#     'location': {'address': '56 9th Avenue, New York 10011',
#      'locality': '9th Avenue, Greenwich Village',
#      'city': 'New York City',
#      'city_id': 280,
#      'latitude': '40.7413222222',
#      'longitude': '-74.0048611111',
#      'zipcode': '10011',
#      'country_id': 216,
#      'locality_verbose': '9th Avenue, Greenwich Village, New York City'},
#     'switch_to_order_menu': 0,
#     'cuisines': 'Steak',
#     'average_cost_for_two': 140,
#     'price_range': 4,
#     'currency': '$',
#     'offers': [],
#     'opentable_support': 0,
#     'is_zomato_book_res': 0,
#     'mezzo_provider': 'OTHER',
#     'is_book_form_web_view': 0,
#     'book_form_web_view_url': '',
#     'book_again_url': '',
#     'thumb': 'https://b.zmtcdn.com/data/pictures/3/16774083/4e7d1e497fcb33aa9181c37bb7a14af1.jpg?fit=around%7C200%3A200&crop=200%3A200%3B%2A%2C%2A',
#     'user_rating': {'aggregate_rating': '4.2',
#      'rating_text': 'Very Good',
#      'rating_color': '5BA829',
#      'votes': '201',
#      'has_fake_reviews': 0},
#     'photos_url': 'https://www.zomato.com/new-york-city/old-homestead-steakhouse-greenwich-village/photos?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1#tabtop',
#     'menu_url': 'https://www.zomato.com/new-york-city/old-homestead-steakhouse-greenwich-village/menu?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1&openSwipeBox=menu&showMinimal=1#tabtop',
#     'featured_image': 'https://b.zmtcdn.com/data/pictures/3/16774083/4e7d1e497fcb33aa9181c37bb7a14af1.jpg',
#     'has_online_delivery': 0,
#     'is_delivering_now': 0,
#     'has_fake_reviews': 0,
#     'include_bogo_offers': True,
#     'deeplink': 'zomato://restaurant/16774083',
#     'is_table_reservation_supported': 0,
#     'has_table_booking': 0,
#     'events_url': 'https://www.zomato.com/new-york-city/old-homestead-steakhouse-greenwich-village/events#tabtop?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#     'establishment_types': []}},
#   {'restaurant': {'R': {'res_id': 16768626},
#     'apikey': '06e95084cb5d3426c57b51987827eb7d',
#     'id': '16768626',
#     'name': 'J.G. Melon',
#     'url': 'https://www.zomato.com/new-york-city/j-g-melon-upper-east-side?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#     'location': {'address': '1291 3rd Avenue 10021',
#      'locality': 'Upper East Side',
#      'city': 'New York City',
#      'city_id': 280,
#      'latitude': '40.7710400000',
#      'longitude': '-73.9592900000',
#      'zipcode': '10021',
#      'country_id': 216,
#      'locality_verbose': 'Upper East Side'},
#     'switch_to_order_menu': 0,
#     'cuisines': 'American, Burger',
#     'average_cost_for_two': 55,
#     'price_range': 3,
#     'currency': '$',
#     'offers': [],
#     'opentable_support': 0,
#     'is_zomato_book_res': 0,
#     'mezzo_provider': 'OTHER',
#     'is_book_form_web_view': 0,
#     'book_form_web_view_url': '',
#     'book_again_url': '',
#     'thumb': 'https://b.zmtcdn.com/data/pictures/chains/6/16768626/1d415cbb01bf89c9d35032af88ec5f81.png?fit=around%7C200%3A200&crop=200%3A200%3B%2A%2C%2A',
#     'user_rating': {'aggregate_rating': '4.4',
#      'rating_text': 'Very Good',
#      'rating_color': '5BA829',
#      'votes': '238',
#      'has_fake_reviews': 0},
#     'photos_url': 'https://www.zomato.com/new-york-city/j-g-melon-upper-east-side/photos?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1#tabtop',
#     'menu_url': 'https://www.zomato.com/new-york-city/j-g-melon-upper-east-side/menu?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1&openSwipeBox=menu&showMinimal=1#tabtop',
#     'featured_image': 'https://b.zmtcdn.com/data/pictures/chains/6/16768626/1d415cbb01bf89c9d35032af88ec5f81.png?output-format=webp',
#     'has_online_delivery': 0,
#     'is_delivering_now': 0,
#     'has_fake_reviews': 0,
#     'include_bogo_offers': True,
#     'deeplink': 'zomato://restaurant/16768626',
#     'is_table_reservation_supported': 0,
#     'has_table_booking': 0,
#     'events_url': 'https://www.zomato.com/new-york-city/j-g-melon-upper-east-side/events#tabtop?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#     'establishment_types': []}},
#   {'restaurant': {'R': {'res_id': 16769240},
#     'apikey': '06e95084cb5d3426c57b51987827eb7d',
#     'id': '16769240',
#     'name': "Junior's Restaurant",
#     'url': 'https://www.zomato.com/new-york-city/juniors-restaurant-downtown-brooklyn?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#     'location': {'address': '386 Flatbush Avenue, Downtown Brooklyn 11238',
#      'locality': 'Downtown Brooklyn',
#      'city': 'New York City',
#      'city_id': 280,
#      'latitude': '40.6760063000',
#      'longitude': '-73.9715803000',
#      'zipcode': '11238',
#      'country_id': 216,
#      'locality_verbose': 'Downtown Brooklyn'},
#     'switch_to_order_menu': 0,
#     'cuisines': 'American, Desserts, Diner',
#     'average_cost_for_two': 60,
#     'price_range': 4,
#     'currency': '$',
#     'offers': [],
#     'opentable_support': 0,
#     'is_zomato_book_res': 0,
#     'mezzo_provider': 'OTHER',
#     'is_book_form_web_view': 0,
#     'book_form_web_view_url': '',
#     'book_again_url': '',
#     'thumb': '',
#     'user_rating': {'aggregate_rating': '4.4',
#      'rating_text': 'Very Good',
#      'rating_color': '5BA829',
#      'votes': '157',
#      'has_fake_reviews': 0},
#     'photos_url': 'https://www.zomato.com/new-york-city/juniors-restaurant-downtown-brooklyn/photos?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1#tabtop',
#     'menu_url': 'https://www.zomato.com/new-york-city/juniors-restaurant-downtown-brooklyn/menu?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1&openSwipeBox=menu&showMinimal=1#tabtop',
#     'featured_image': '',
#     'has_online_delivery': 0,
#     'is_delivering_now': 0,
#     'has_fake_reviews': 0,
#     'include_bogo_offers': True,
#     'deeplink': 'zomato://restaurant/16769240',
#     'is_table_reservation_supported': 0,
#     'has_table_booking': 0,
#     'events_url': 'https://www.zomato.com/new-york-city/juniors-restaurant-downtown-brooklyn/events#tabtop?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#     'establishment_types': []}},
#   {'restaurant': {'R': {'res_id': 16773261},
#     'apikey': '06e95084cb5d3426c57b51987827eb7d',
#     'id': '16773261',
#     'name': 'Negril Village',
#     'url': 'https://www.zomato.com/new-york-city/negril-village-greenwich-village?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#     'location': {'address': '70 West 3rd Street 10012',
#      'locality': 'Greenwich Village',
#      'city': 'New York City',
#      'city_id': 280,
#      'latitude': '40.7293500000',
#      'longitude': '-73.9984100000',
#      'zipcode': '10012',
#      'country_id': 216,
#      'locality_verbose': 'Greenwich Village'},
#     'switch_to_order_menu': 0,
#     'cuisines': 'Caribbean, Latin American, Southern',
#     'average_cost_for_two': 150,
#     'price_range': 4,
#     'currency': '$',
#     'offers': [],
#     'opentable_support': 0,
#     'is_zomato_book_res': 0,
#     'mezzo_provider': 'OTHER',
#     'is_book_form_web_view': 0,
#     'book_form_web_view_url': '',
#     'book_again_url': '',
#     'thumb': 'https://b.zmtcdn.com/data/res_imagery/16773261_RESTAURANT_76cf474bd9976831af156a2644fb0101_c.png?fit=around%7C200%3A200&crop=200%3A200%3B%2A%2C%2A',
#     'user_rating': {'aggregate_rating': '4.5',
#      'rating_text': 'Excellent',
#      'rating_color': '3F7E00',
#      'votes': '231',
#      'has_fake_reviews': 0},
#     'photos_url': 'https://www.zomato.com/new-york-city/negril-village-greenwich-village/photos?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1#tabtop',
#     'menu_url': 'https://www.zomato.com/new-york-city/negril-village-greenwich-village/menu?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1&openSwipeBox=menu&showMinimal=1#tabtop',
#     'featured_image': 'https://b.zmtcdn.com/data/res_imagery/16773261_RESTAURANT_76cf474bd9976831af156a2644fb0101_c.png',
#     'has_online_delivery': 0,
#     'is_delivering_now': 0,
#     'has_fake_reviews': 0,
#     'include_bogo_offers': True,
#     'deeplink': 'zomato://restaurant/16773261',
#     'is_table_reservation_supported': 0,
#     'has_table_booking': 0,
#     'events_url': 'https://www.zomato.com/new-york-city/negril-village-greenwich-village/events#tabtop?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#     'establishment_types': []}},
#   {'restaurant': {'R': {'res_id': 16758575},
#     'apikey': '06e95084cb5d3426c57b51987827eb7d',
#     'id': '16758575',
#     'name': '230 Fifth',
#     'url': 'https://www.zomato.com/new-york-city/230-fifth-gramercy-flatiron?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#     'location': {'address': '230 5th Avenue, New York 10001',
#      'locality': 'Gramercy-Flatiron',
#      'city': 'New York City',
#      'city_id': 280,
#      'latitude': '40.7439010000',
#      'longitude': '-73.9878480000',
#      'zipcode': '10001',
#      'country_id': 216,
#      'locality_verbose': 'Gramercy-Flatiron'},
#     'switch_to_order_menu': 0,
#     'cuisines': 'Bar Food',
#     'average_cost_for_two': 120,
#     'price_range': 4,
#     'currency': '$',
#     'offers': [],
#     'opentable_support': 0,
#     'is_zomato_book_res': 0,
#     'mezzo_provider': 'OTHER',
#     'is_book_form_web_view': 0,
#     'book_form_web_view_url': '',
#     'book_again_url': '',
#     'thumb': 'https://b.zmtcdn.com/data/res_imagery/16758575_RESTAURANT_270e9aa0d8a4917eb9641d1673114dfc_c.png?fit=around%7C200%3A200&crop=200%3A200%3B%2A%2C%2A',
#     'user_rating': {'aggregate_rating': '3.9',
#      'rating_text': 'Good',
#      'rating_color': '9ACD32',
#      'votes': '140',
#      'has_fake_reviews': 0},
#     'photos_url': 'https://www.zomato.com/new-york-city/230-fifth-gramercy-flatiron/photos?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1#tabtop',
#     'menu_url': 'https://www.zomato.com/new-york-city/230-fifth-gramercy-flatiron/menu?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1&openSwipeBox=menu&showMinimal=1#tabtop',
#     'featured_image': 'https://b.zmtcdn.com/data/res_imagery/16758575_RESTAURANT_270e9aa0d8a4917eb9641d1673114dfc_c.png',
#     'has_online_delivery': 0,
#     'is_delivering_now': 0,
#     'has_fake_reviews': 0,
#     'include_bogo_offers': True,
#     'deeplink': 'zomato://restaurant/16758575',
#     'is_table_reservation_supported': 0,
#     'has_table_booking': 0,
#     'events_url': 'https://www.zomato.com/new-york-city/230-fifth-gramercy-flatiron/events#tabtop?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#     'establishment_types': []}},
#   {'restaurant': {'R': {'res_id': 16760836},
#     'apikey': '06e95084cb5d3426c57b51987827eb7d',
#     'id': '16760836',
#     'name': 'Blind Tiger',
#     'url': 'https://www.zomato.com/new-york-city/blind-tiger-west-village?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#     'location': {'address': '281 Bleecker Street, New York 10014',
#      'locality': 'West Village',
#      'city': 'New York City',
#      'city_id': 280,
#      'latitude': '40.7318611111',
#      'longitude': '-74.0032416667',
#      'zipcode': '10014',
#      'country_id': 216,
#      'locality_verbose': 'West Village'},
#     'switch_to_order_menu': 0,
#     'cuisines': 'American, Bar Food',
#     'average_cost_for_two': 70,
#     'price_range': 4,
#     'currency': '$',
#     'offers': [],
#     'opentable_support': 0,
#     'is_zomato_book_res': 0,
#     'mezzo_provider': 'OTHER',
#     'is_book_form_web_view': 0,
#     'book_form_web_view_url': '',
#     'book_again_url': '',
#     'thumb': 'https://b.zmtcdn.com/data/res_imagery/16760836_RESTAURANT_04be8d67dde3714ff7db48bf43722ec3_c.jpg?fit=around%7C200%3A200&crop=200%3A200%3B%2A%2C%2A',
#     'user_rating': {'aggregate_rating': '4.2',
#      'rating_text': 'Very Good',
#      'rating_color': '5BA829',
#      'votes': '110',
#      'has_fake_reviews': 0},
#     'photos_url': 'https://www.zomato.com/new-york-city/blind-tiger-west-village/photos?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1#tabtop',
#     'menu_url': 'https://www.zomato.com/new-york-city/blind-tiger-west-village/menu?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1&openSwipeBox=menu&showMinimal=1#tabtop',
#     'featured_image': 'https://b.zmtcdn.com/data/res_imagery/16760836_RESTAURANT_04be8d67dde3714ff7db48bf43722ec3_c.jpg',
#     'has_online_delivery': 0,
#     'is_delivering_now': 0,
#     'has_fake_reviews': 0,
#     'include_bogo_offers': True,
#     'deeplink': 'zomato://restaurant/16760836',
#     'is_table_reservation_supported': 0,
#     'has_table_booking': 0,
#     'events_url': 'https://www.zomato.com/new-york-city/blind-tiger-west-village/events#tabtop?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#     'establishment_types': []}},
#   {'restaurant': {'R': {'res_id': 16787069},
#     'apikey': '06e95084cb5d3426c57b51987827eb7d',
#     'id': '16787069',
#     'name': 'Catch',
#     'url': 'https://www.zomato.com/new-york-city/catch-meat-packing-district?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#     'location': {'address': '21 9th Avenue, New York 10014',
#      'locality': '9th Avenue, Meat Packing District',
#      'city': 'New York City',
#      'city_id': 280,
#      'latitude': '40.7401472222',
#      'longitude': '-74.0060666667',
#      'zipcode': '10014',
#      'country_id': 216,
#      'locality_verbose': '9th Avenue, Meat Packing District, New York City'},
#     'switch_to_order_menu': 0,
#     'cuisines': 'Seafood, New American',
#     'average_cost_for_two': 110,
#     'price_range': 4,
#     'currency': '$',
#     'offers': [],
#     'opentable_support': 0,
#     'is_zomato_book_res': 0,
#     'mezzo_provider': 'OTHER',
#     'is_book_form_web_view': 0,
#     'book_form_web_view_url': '',
#     'book_again_url': '',
#     'thumb': 'https://b.zmtcdn.com/data/res_imagery/16787069_RESTAURANT_93c3bc7d612f50ce2e83200c927aaa4d_c.jpg?fit=around%7C200%3A200&crop=200%3A200%3B%2A%2C%2A',
#     'user_rating': {'aggregate_rating': '4.0',
#      'rating_text': 'Very Good',
#      'rating_color': '5BA829',
#      'votes': '112',
#      'has_fake_reviews': 0},
#     'photos_url': 'https://www.zomato.com/new-york-city/catch-meat-packing-district/photos?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1#tabtop',
#     'menu_url': 'https://www.zomato.com/new-york-city/catch-meat-packing-district/menu?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1&openSwipeBox=menu&showMinimal=1#tabtop',
#     'featured_image': 'https://b.zmtcdn.com/data/res_imagery/16787069_RESTAURANT_93c3bc7d612f50ce2e83200c927aaa4d_c.jpg',
#     'has_online_delivery': 0,
#     'is_delivering_now': 0,
#     'has_fake_reviews': 0,
#     'include_bogo_offers': True,
#     'deeplink': 'zomato://restaurant/16787069',
#     'is_table_reservation_supported': 0,
#     'has_table_booking': 0,
#     'events_url': 'https://www.zomato.com/new-york-city/catch-meat-packing-district/events#tabtop?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#     'establishment_types': []}},
#   {'restaurant': {'R': {'res_id': 16782307},
#     'apikey': '06e95084cb5d3426c57b51987827eb7d',
#     'id': '16782307',
#     'name': "PDT (Please Don't Tell)",
#     'url': 'https://www.zomato.com/new-york-city/pdt-please-dont-tell-east-village?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#     'location': {'address': '113 Saint Marks Place, New York 10009',
#      'locality': 'East Village',
#      'city': 'New York City',
#      'city_id': 280,
#      'latitude': '40.7269027778',
#      'longitude': '-73.9839027778',
#      'zipcode': '10009',
#      'country_id': 216,
#      'locality_verbose': 'East Village'},
#     'switch_to_order_menu': 0,
#     'cuisines': 'Bar Food',
#     'average_cost_for_two': 100,
#     'price_range': 4,
#     'currency': '$',
#     'offers': [],
#     'opentable_support': 0,
#     'is_zomato_book_res': 0,
#     'mezzo_provider': 'OTHER',
#     'is_book_form_web_view': 0,
#     'book_form_web_view_url': '',
#     'book_again_url': '',
#     'thumb': 'https://b.zmtcdn.com/data/res_imagery/16782307_RESTAURANT_3bdf3c8c58dc6415977b16b74b38a378_c.jpg?fit=around%7C200%3A200&crop=200%3A200%3B%2A%2C%2A',
#     'user_rating': {'aggregate_rating': '4.1',
#      'rating_text': 'Very Good',
#      'rating_color': '5BA829',
#      'votes': '131',
#      'has_fake_reviews': 0},
#     'photos_url': 'https://www.zomato.com/new-york-city/pdt-please-dont-tell-east-village/photos?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1#tabtop',
#     'menu_url': 'https://www.zomato.com/new-york-city/pdt-please-dont-tell-east-village/menu?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1&openSwipeBox=menu&showMinimal=1#tabtop',
#     'featured_image': 'https://b.zmtcdn.com/data/res_imagery/16782307_RESTAURANT_3bdf3c8c58dc6415977b16b74b38a378_c.jpg',
#     'has_online_delivery': 0,
#     'is_delivering_now': 0,
#     'has_fake_reviews': 0,
#     'include_bogo_offers': True,
#     'deeplink': 'zomato://restaurant/16782307',
#     'is_table_reservation_supported': 0,
#     'has_table_booking': 0,
#     'events_url': 'https://www.zomato.com/new-york-city/pdt-please-dont-tell-east-village/events#tabtop?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#     'establishment_types': []}},
#   {'restaurant': {'R': {'res_id': 16782736},
#     'apikey': '06e95084cb5d3426c57b51987827eb7d',
#     'id': '16782736',
#     'name': "L'Artusi",
#     'url': 'https://www.zomato.com/new-york-city/lartusi-1-greenwich-village?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#     'location': {'address': '228 West 10th Street, New York 10014',
#      'locality': 'Greenwich Village',
#      'city': 'New York City',
#      'city_id': 280,
#      'latitude': '40.7337110000',
#      'longitude': '-74.0051290000',
#      'zipcode': '10014',
#      'country_id': 216,
#      'locality_verbose': 'Greenwich Village'},
#     'switch_to_order_menu': 0,
#     'cuisines': 'Italian',
#     'average_cost_for_two': 120,
#     'price_range': 4,
#     'currency': '$',
#     'offers': [],
#     'opentable_support': 0,
#     'is_zomato_book_res': 0,
#     'mezzo_provider': 'OTHER',
#     'is_book_form_web_view': 0,
#     'book_form_web_view_url': '',
#     'book_again_url': '',
#     'thumb': 'https://b.zmtcdn.com/data/pictures/6/16782736/c4e7990283a6a7407d45f132194d397f.jpg?fit=around%7C200%3A200&crop=200%3A200%3B%2A%2C%2A',
#     'user_rating': {'aggregate_rating': '4.4',
#      'rating_text': 'Very Good',
#      'rating_color': '5BA829',
#      'votes': '151',
#      'has_fake_reviews': 0},
#     'photos_url': 'https://www.zomato.com/new-york-city/lartusi-1-greenwich-village/photos?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1#tabtop',
#     'menu_url': 'https://www.zomato.com/new-york-city/lartusi-1-greenwich-village/menu?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1&openSwipeBox=menu&showMinimal=1#tabtop',
#     'featured_image': 'https://b.zmtcdn.com/data/pictures/6/16782736/c4e7990283a6a7407d45f132194d397f.jpg',
#     'has_online_delivery': 0,
#     'is_delivering_now': 0,
#     'has_fake_reviews': 0,
#     'include_bogo_offers': True,
#     'deeplink': 'zomato://restaurant/16782736',
#     'is_table_reservation_supported': 0,
#     'has_table_booking': 0,
#     'events_url': 'https://www.zomato.com/new-york-city/lartusi-1-greenwich-village/events#tabtop?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#     'establishment_types': []}},
#   {'restaurant': {'R': {'res_id': 16780334},
#     'apikey': '06e95084cb5d3426c57b51987827eb7d',
#     'id': '16780334',
#     'name': 'Uva',
#     'url': 'https://www.zomato.com/new-york-city/uva-upper-east-side?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#     'location': {'address': '1486 2nd Avenue 10075',
#      'locality': 'Upper East Side',
#      'city': 'New York City',
#      'city_id': 280,
#      'latitude': '40.7721600000',
#      'longitude': '-73.9555800000',
#      'zipcode': '10075',
#      'country_id': 216,
#      'locality_verbose': 'Upper East Side'},
#     'switch_to_order_menu': 0,
#     'cuisines': 'Italian',
#     'average_cost_for_two': 55,
#     'price_range': 3,
#     'currency': '$',
#     'offers': [],
#     'opentable_support': 0,
#     'is_zomato_book_res': 0,
#     'mezzo_provider': 'OTHER',
#     'is_book_form_web_view': 0,
#     'book_form_web_view_url': '',
#     'book_again_url': '',
#     'thumb': 'https://b.zmtcdn.com/data/res_imagery/16780334_RESTAURANT_542aa1fa63d351feb5f791f5693bc721_c.jpg?fit=around%7C200%3A200&crop=200%3A200%3B%2A%2C%2A',
#     'user_rating': {'aggregate_rating': '4.4',
#      'rating_text': 'Very Good',
#      'rating_color': '5BA829',
#      'votes': '159',
#      'has_fake_reviews': 0},
#     'photos_url': 'https://www.zomato.com/new-york-city/uva-upper-east-side/photos?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1#tabtop',
#     'menu_url': 'https://www.zomato.com/new-york-city/uva-upper-east-side/menu?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1&openSwipeBox=menu&showMinimal=1#tabtop',
#     'featured_image': 'https://b.zmtcdn.com/data/res_imagery/16780334_RESTAURANT_542aa1fa63d351feb5f791f5693bc721_c.jpg',
#     'has_online_delivery': 0,
#     'is_delivering_now': 0,
#     'has_fake_reviews': 0,
#     'include_bogo_offers': True,
#     'deeplink': 'zomato://restaurant/16780334',
#     'is_table_reservation_supported': 0,
#     'has_table_booking': 0,
#     'events_url': 'https://www.zomato.com/new-york-city/uva-upper-east-side/events#tabtop?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#     'establishment_types': []}}]}

# %%
# categories
results = requests.get(url=url+"categories?",headers=headers)

# %%
results.json()
# Out:
# {'categories': [{'categories': {'id': 1, 'name': 'Delivery'}},
#   {'categories': {'id': 2, 'name': 'Dine-out'}},
#   {'categories': {'id': 3, 'name': 'Nightlife'}},
#   {'categories': {'id': 4, 'name': 'Catching-up'}},
#   {'categories': {'id': 5, 'name': 'Takeaway'}},
#   {'categories': {'id': 6, 'name': 'Cafes'}},
#   {'categories': {'id': 7, 'name': 'Daily Menus'}},
#   {'categories': {'id': 8, 'name': 'Breakfast'}},
#   {'categories': {'id': 9, 'name': 'Lunch'}},
#   {'categories': {'id': 10, 'name': 'Dinner'}},
#   {'categories': {'id': 11, 'name': 'Pubs & Bars'}},
#   {'categories': {'id': 13, 'name': 'Pocket Friendly Delivery'}},
#   {'categories': {'id': 14, 'name': 'Clubs & Lounges'}}]}

# %%
# Lunch
headers= {
    "user-key":Key,
    "Accept": "application/json" 
}
params= {
    "category": 9,
    "entity_id": 280,
    "entity_type": "city",
}

# search
lunch_results = requests.get(url=url+"search?",headers=headers,params=params)

# %%
lunch_results.json()
# Out:
# {'results_found': 37229,
#  'results_start': 0,
#  'results_shown': 20,
#  'restaurants': [{'restaurant': {'R': {'res_id': 16771079},
#     'apikey': '06e95084cb5d3426c57b51987827eb7d',
#     'id': '16771079',
#     'name': "Lombardi's Pizza",
#     'url': 'https://www.zomato.com/new-york-city/lombardis-pizza-lower-east-side?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#     'location': {'address': '32 Spring Street, New York 10012',
#      'locality': 'Spring Street, Lower East Side',
#      'city': 'New York City',
#      'city_id': 280,
#      'latitude': '40.7216750000',
#      'longitude': '-73.9955888889',
#      'zipcode': '10012',
#      'country_id': 216,
#      'locality_verbose': 'Spring Street, Lower East Side, New York City'},
#     'switch_to_order_menu': 0,
#     'cuisines': 'Pizza, Italian',
#     'average_cost_for_two': 50,
#     'price_range': 3,
#     'currency': '$',
#     'offers': [],
#     'opentable_support': 0,
#     'is_zomato_book_res': 0,
#     'mezzo_provider': 'OTHER',
#     'is_book_form_web_view': 0,
#     'book_form_web_view_url': '',
#     'book_again_url': '',
#     'thumb': 'https://b.zmtcdn.com/data/res_imagery/16771079_RESTAURANT_da60c9abb32fa64cddc148a2795ae43c_c.jpg?fit=around%7C200%3A200&crop=200%3A200%3B%2A%2C%2A',
#     'user_rating': {'aggregate_rating': '4.9',
#      'rating_text': 'Excellent',
#      'rating_color': '3F7E00',
#      'votes': '1471',
#      'has_fake_reviews': 0},
#     'photos_url': 'https://www.zomato.com/new-york-city/lombardis-pizza-lower-east-side/photos?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1#tabtop',
#     'menu_url': 'https://www.zomato.com/new-york-city/lombardis-pizza-lower-east-side/menu?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1&openSwipeBox=menu&showMinimal=1#tabtop',
#     'featured_image': 'https://b.zmtcdn.com/data/res_imagery/16771079_RESTAURANT_da60c9abb32fa64cddc148a2795ae43c_c.jpg',
#     'has_online_delivery': 0,
#     'is_delivering_now': 0,
#     'has_fake_reviews': 0,
#     'include_bogo_offers': True,
#     'deeplink': 'zomato://restaurant/16771079',
#     'is_table_reservation_supported': 0,
#     'has_table_booking': 0,
#     'events_url': 'https://www.zomato.com/new-york-city/lombardis-pizza-lower-east-side/events#tabtop?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#     'establishment_types': []}},
#   {'restaurant': {'R': {'res_id': 16769546},
#     'apikey': '06e95084cb5d3426c57b51987827eb7d',
#     'id': '16769546',
#     'name': "Katz's Delicatessen",
#     'url': 'https://www.zomato.com/new-york-city/katzs-delicatessen-lower-east-side?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#     'location': {'address': '205 East Houston Street, New York 10002',
#      'locality': 'Lower East Side',
#      'city': 'New York City',
#      'city_id': 280,
#      'latitude': '40.7223277778',
#      'longitude': '-73.9873500000',
#      'zipcode': '10002',
#      'country_id': 216,
#      'locality_verbose': 'Lower East Side'},
#     'switch_to_order_menu': 0,
#     'cuisines': 'Sandwich',
#     'average_cost_for_two': 30,
#     'price_range': 2,
#     'currency': '$',
#     'offers': [],
#     'opentable_support': 0,
#     'is_zomato_book_res': 0,
#     'mezzo_provider': 'OTHER',
#     'is_book_form_web_view': 0,
#     'book_form_web_view_url': '',
#     'book_again_url': '',
#     'thumb': 'https://b.zmtcdn.com/data/pictures/6/16769546/48ab9901ddf191d13ade07221b43ba93.jpg?fit=around%7C200%3A200&crop=200%3A200%3B%2A%2C%2A',
#     'user_rating': {'aggregate_rating': '4.9',
#      'rating_text': 'Excellent',
#      'rating_color': '3F7E00',
#      'votes': '2501',
#      'has_fake_reviews': 0},
#     'photos_url': 'https://www.zomato.com/new-york-city/katzs-delicatessen-lower-east-side/photos?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1#tabtop',
#     'menu_url': 'https://www.zomato.com/new-york-city/katzs-delicatessen-lower-east-side/menu?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1&openSwipeBox=menu&showMinimal=1#tabtop',
#     'featured_image': 'https://b.zmtcdn.com/data/pictures/6/16769546/48ab9901ddf191d13ade07221b43ba93.jpg',
#     'has_online_delivery': 0,
#     'is_delivering_now': 0,
#     'has_fake_reviews': 0,
#     'include_bogo_offers': True,
#     'deeplink': 'zomato://restaurant/16769546',
#     'is_table_reservation_supported': 0,
#     'has_table_booking': 0,
#     'events_url': 'https://www.zomato.com/new-york-city/katzs-delicatessen-lower-east-side/events#tabtop?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#     'establishment_types': []}},
#   {'restaurant': {'R': {'res_id': 16767332},
#     'apikey': '06e95084cb5d3426c57b51987827eb7d',
#     'id': '16767332',
#     'name': "Grimaldi's Pizzeria",
#     'url': 'https://www.zomato.com/new-york-city/grimaldis-pizzeria-dumbo?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#     'location': {'address': '1 Front Street, Brooklyn 11201',
#      'locality': 'Front Street, DUMBO',
#      'city': 'New York City',
#      'city_id': 280,
#      'latitude': '40.7025138889',
#      'longitude': '-73.9932722222',
#      'zipcode': '11201',
#      'country_id': 216,
#      'locality_verbose': 'Front Street, DUMBO, New York City'},
#     'switch_to_order_menu': 0,
#     'cuisines': 'Pizza, Italian',
#     'average_cost_for_two': 50,
#     'price_range': 3,
#     'currency': '$',
#     'offers': [],
#     'opentable_support': 0,
#     'is_zomato_book_res': 0,
#     'mezzo_provider': 'OTHER',
#     'is_book_form_web_view': 0,
#     'book_form_web_view_url': '',
#     'book_again_url': '',
#     'thumb': 'https://b.zmtcdn.com/data/pictures/chains/2/16767332/fa6705919261e9c27ae46737d56a0faa.jpg?fit=around%7C200%3A200&crop=200%3A200%3B%2A%2C%2A',
#     'user_rating': {'aggregate_rating': '4.6',
#      'rating_text': 'Excellent',
#      'rating_color': '3F7E00',
#      'votes': '945',
#      'has_fake_reviews': 0},
#     'photos_url': 'https://www.zomato.com/new-york-city/grimaldis-pizzeria-dumbo/photos?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1#tabtop',
#     'menu_url': 'https://www.zomato.com/new-york-city/grimaldis-pizzeria-dumbo/menu?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1&openSwipeBox=menu&showMinimal=1#tabtop',
#     'featured_image': 'https://b.zmtcdn.com/data/pictures/chains/2/16767332/fa6705919261e9c27ae46737d56a0faa.jpg',
#     'has_online_delivery': 0,
#     'is_delivering_now': 0,
#     'has_fake_reviews': 0,
#     'include_bogo_offers': True,
#     'deeplink': 'zomato://restaurant/16767332',
#     'is_table_reservation_supported': 0,
#     'has_table_booking': 0,
#     'events_url': 'https://www.zomato.com/new-york-city/grimaldis-pizzeria-dumbo/events#tabtop?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#     'establishment_types': []}},
#   {'restaurant': {'R': {'res_id': 16780467},
#     'apikey': '06e95084cb5d3426c57b51987827eb7d',
#     'id': '16780467',
#     'name': 'Veselka',
#     'url': 'https://www.zomato.com/new-york-city/veselka-east-village?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#     'location': {'address': '144 2nd Avenue 10003',
#      'locality': 'East Village',
#      'city': 'New York City',
#      'city_id': 280,
#      'latitude': '40.7287300000',
#      'longitude': '-73.9870800000',
#      'zipcode': '10003',
#      'country_id': 216,
#      'locality_verbose': 'East Village'},
#     'switch_to_order_menu': 0,
#     'cuisines': 'Ukrainian',
#     'average_cost_for_two': 40,
#     'price_range': 3,
#     'currency': '$',
#     'offers': [],
#     'opentable_support': 0,
#     'is_zomato_book_res': 0,
#     'mezzo_provider': 'OTHER',
#     'is_book_form_web_view': 0,
#     'book_form_web_view_url': '',
#     'book_again_url': '',
#     'thumb': 'https://b.zmtcdn.com/data/pictures/7/16780467/95079d815c89a8bfafa31e73f81ce3ba.jpg?fit=around%7C200%3A200&crop=200%3A200%3B%2A%2C%2A',
#     'user_rating': {'aggregate_rating': '4.6',
#      'rating_text': 'Excellent',
#      'rating_color': '3F7E00',
#      'votes': '699',
#      'has_fake_reviews': 0},
#     'photos_url': 'https://www.zomato.com/new-york-city/veselka-east-village/photos?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1#tabtop',
#     'menu_url': 'https://www.zomato.com/new-york-city/veselka-east-village/menu?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1&openSwipeBox=menu&showMinimal=1#tabtop',
#     'featured_image': 'https://b.zmtcdn.com/data/pictures/7/16780467/95079d815c89a8bfafa31e73f81ce3ba.jpg',
#     'has_online_delivery': 0,
#     'is_delivering_now': 0,
#     'has_fake_reviews': 0,
#     'include_bogo_offers': True,
#     'deeplink': 'zomato://restaurant/16780467',
#     'is_table_reservation_supported': 0,
#     'has_table_booking': 0,
#     'events_url': 'https://www.zomato.com/new-york-city/veselka-east-village/events#tabtop?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#     'establishment_types': []}},
#   {'restaurant': {'R': {'res_id': 16779248},
#     'apikey': '06e95084cb5d3426c57b51987827eb7d',
#     'id': '16779248',
#     'name': 'Tao',
#     'url': 'https://www.zomato.com/new-york-city/tao-midtown?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#     'location': {'address': '42 E 58th Street, New York 10022',
#      'locality': 'Midtown',
#      'city': 'New York City',
#      'city_id': 280,
#      'latitude': '40.7627111111',
#      'longitude': '-73.9713750000',
#      'zipcode': '10022',
#      'country_id': 216,
#      'locality_verbose': 'Midtown'},
#     'switch_to_order_menu': 0,
#     'cuisines': 'Asian, Chinese',
#     'average_cost_for_two': 150,
#     'price_range': 4,
#     'currency': '$',
#     'offers': [],
#     'opentable_support': 0,
#     'is_zomato_book_res': 0,
#     'mezzo_provider': 'OTHER',
#     'is_book_form_web_view': 0,
#     'book_form_web_view_url': '',
#     'book_again_url': '',
#     'thumb': 'https://b.zmtcdn.com/data/res_imagery/16779248_RESTAURANT_68d0ceba78997b23ff011573ee029f13_c.jpg?fit=around%7C200%3A200&crop=200%3A200%3B%2A%2C%2A',
#     'user_rating': {'aggregate_rating': '4.4',
#      'rating_text': 'Very Good',
#      'rating_color': '5BA829',
#      'votes': '699',
#      'has_fake_reviews': 0},
#     'photos_url': 'https://www.zomato.com/new-york-city/tao-midtown/photos?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1#tabtop',
#     'menu_url': 'https://www.zomato.com/new-york-city/tao-midtown/menu?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1&openSwipeBox=menu&showMinimal=1#tabtop',
#     'featured_image': 'https://b.zmtcdn.com/data/res_imagery/16779248_RESTAURANT_68d0ceba78997b23ff011573ee029f13_c.jpg',
#     'has_online_delivery': 0,
#     'is_delivering_now': 0,
#     'has_fake_reviews': 0,
#     'include_bogo_offers': True,
#     'deeplink': 'zomato://restaurant/16779248',
#     'is_table_reservation_supported': 0,
#     'has_table_booking': 0,
#     'events_url': 'https://www.zomato.com/new-york-city/tao-midtown/events#tabtop?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#     'establishment_types': []}},
#   {'restaurant': {'R': {'res_id': 16760100},
#     'apikey': '06e95084cb5d3426c57b51987827eb7d',
#     'id': '16760100',
#     'name': 'Balthazar',
#     'url': 'https://www.zomato.com/new-york-city/balthazar-soho?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#     'location': {'address': '80 Spring Street 10012',
#      'locality': 'Soho',
#      'city': 'New York City',
#      'city_id': 280,
#      'latitude': '40.7225900000',
#      'longitude': '-73.9980500000',
#      'zipcode': '10012',
#      'country_id': 216,
#      'locality_verbose': 'Soho'},
#     'switch_to_order_menu': 0,
#     'cuisines': 'French, Seafood, Bakery',
#     'average_cost_for_two': 140,
#     'price_range': 4,
#     'currency': '$',
#     'offers': [],
#     'opentable_support': 0,
#     'is_zomato_book_res': 0,
#     'mezzo_provider': 'OTHER',
#     'is_book_form_web_view': 0,
#     'book_form_web_view_url': '',
#     'book_again_url': '',
#     'thumb': 'https://b.zmtcdn.com/data/pictures/0/16760100/2cee8640b74a1e53fde146c9c90f5213.png?fit=around%7C200%3A200&crop=200%3A200%3B%2A%2C%2A',
#     'user_rating': {'aggregate_rating': '4.6',
#      'rating_text': 'Excellent',
#      'rating_color': '3F7E00',
#      'votes': '1861',
#      'has_fake_reviews': 0},
#     'photos_url': 'https://www.zomato.com/new-york-city/balthazar-soho/photos?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1#tabtop',
#     'menu_url': 'https://www.zomato.com/new-york-city/balthazar-soho/menu?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1&openSwipeBox=menu&showMinimal=1#tabtop',
#     'featured_image': 'https://b.zmtcdn.com/data/pictures/0/16760100/2cee8640b74a1e53fde146c9c90f5213.png',
#     'has_online_delivery': 0,
#     'is_delivering_now': 0,
#     'has_fake_reviews': 0,
#     'include_bogo_offers': True,
#     'deeplink': 'zomato://restaurant/16760100',
#     'is_table_reservation_supported': 0,
#     'has_table_booking': 0,
#     'events_url': 'https://www.zomato.com/new-york-city/balthazar-soho/events#tabtop?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#     'establishment_types': []}},
#   {'restaurant': {'R': {'res_id': 16775039},
#     'apikey': '06e95084cb5d3426c57b51987827eb7d',
#     'id': '16775039',
#     'name': 'Peter Luger Steak House',
#     'url': 'https://www.zomato.com/new-york-city/peter-luger-steak-house-south-side?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#     'location': {'address': '178 Broadway, Brooklyn 11211',
#      'locality': 'South Side',
#      'city': 'New York City',
#      'city_id': 280,
#      'latitude': '40.7098777778',
#      'longitude': '-73.9623416667',
#      'zipcode': '11211',
#      'country_id': 216,
#      'locality_verbose': 'South Side'},
#     'switch_to_order_menu': 0,
#     'cuisines': 'Steak, American, German, Burger',
#     'average_cost_for_two': 150,
#     'price_range': 4,
#     'currency': '$',
#     'offers': [],
#     'opentable_support': 0,
#     'is_zomato_book_res': 0,
#     'mezzo_provider': 'OTHER',
#     'is_book_form_web_view': 0,
#     'book_form_web_view_url': '',
#     'book_again_url': '',
#     'thumb': 'https://b.zmtcdn.com/data/reviews_photos/ea9/ed66f37a5492836605ec71582db68ea9_1441919144.jpg?fit=around%7C200%3A200&crop=200%3A200%3B%2A%2C%2A',
#     'user_rating': {'aggregate_rating': '4.7',
#      'rating_text': 'Excellent',
#      'rating_color': '3F7E00',
#      'votes': '1115',
#      'has_fake_reviews': 0},
#     'photos_url': 'https://www.zomato.com/new-york-city/peter-luger-steak-house-south-side/photos?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1#tabtop',
#     'menu_url': 'https://www.zomato.com/new-york-city/peter-luger-steak-house-south-side/menu?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1&openSwipeBox=menu&showMinimal=1#tabtop',
#     'featured_image': 'https://b.zmtcdn.com/data/reviews_photos/ea9/ed66f37a5492836605ec71582db68ea9_1441919144.jpg',
#     'has_online_delivery': 0,
#     'is_delivering_now': 0,
#     'has_fake_reviews': 0,
#     'include_bogo_offers': True,
#     'deeplink': 'zomato://restaurant/16775039',
#     'is_table_reservation_supported': 0,
#     'has_table_booking': 0,
#     'events_url': 'https://www.zomato.com/new-york-city/peter-luger-steak-house-south-side/events#tabtop?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#     'establishment_types': []}},
#   {'restaurant': {'R': {'res_id': 16762160},
#     'apikey': '06e95084cb5d3426c57b51987827eb7d',
#     'id': '16762160',
#     'name': "Carmine's Italian Restaurant",
#     'url': 'https://www.zomato.com/new-york-city/carmines-italian-restaurant-gramercy?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#     'location': {'address': '200 West 44th Street, btwn Broadway & 8th Avenue 10036',
#      'locality': 'West 44th Street, Gramercy',
#      'city': 'New York City',
#      'city_id': 280,
#      'latitude': '40.7579000000',
#      'longitude': '-73.9875700000',
#      'zipcode': '10036',
#      'country_id': 216,
#      'locality_verbose': 'West 44th Street, Gramercy, New York City'},
#     'switch_to_order_menu': 0,
#     'cuisines': 'Italian, Southern',
#     'average_cost_for_two': 100,
#     'price_range': 4,
#     'currency': '$',
#     'offers': [],
#     'opentable_support': 0,
#     'is_zomato_book_res': 0,
#     'mezzo_provider': 'OTHER',
#     'is_book_form_web_view': 0,
#     'book_form_web_view_url': '',
#     'book_again_url': '',
#     'thumb': 'https://b.zmtcdn.com/data/pictures/0/16762160/7f5654c601548a24af81beb345d99f1b.jpg?fit=around%7C200%3A200&crop=200%3A200%3B%2A%2C%2A',
#     'user_rating': {'aggregate_rating': '4.8',
#      'rating_text': 'Excellent',
#      'rating_color': '3F7E00',
#      'votes': '1028',
#      'has_fake_reviews': 0},
#     'photos_url': 'https://www.zomato.com/new-york-city/carmines-italian-restaurant-gramercy/photos?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1#tabtop',
#     'menu_url': 'https://www.zomato.com/new-york-city/carmines-italian-restaurant-gramercy/menu?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1&openSwipeBox=menu&showMinimal=1#tabtop',
#     'featured_image': 'https://b.zmtcdn.com/data/pictures/0/16762160/7f5654c601548a24af81beb345d99f1b.jpg?output-format=webp',
#     'has_online_delivery': 0,
#     'is_delivering_now': 0,
#     'has_fake_reviews': 0,
#     'include_bogo_offers': True,
#     'deeplink': 'zomato://restaurant/16762160',
#     'is_table_reservation_supported': 0,
#     'has_table_booking': 0,
#     'events_url': 'https://www.zomato.com/new-york-city/carmines-italian-restaurant-gramercy/events#tabtop?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#     'establishment_types': []}},
#   {'restaurant': {'R': {'res_id': 16777320},
#     'apikey': '06e95084cb5d3426c57b51987827eb7d',
#     'id': '16777320',
#     'name': 'Serendipity 3',
#     'url': 'https://www.zomato.com/new-york-city/serendipity-3-upper-east-side?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#     'location': {'address': '225 East 60th Street 10022',
#      'locality': 'Upper East Side',
#      'city': 'New York City',
#      'city_id': 280,
#      'latitude': '40.7618668000',
#      'longitude': '-73.9649001000',
#      'zipcode': '10022',
#      'country_id': 216,
#      'locality_verbose': 'Upper East Side'},
#     'switch_to_order_menu': 0,
#     'cuisines': 'American, Desserts',
#     'average_cost_for_two': 75,
#     'price_range': 4,
#     'currency': '$',
#     'offers': [],
#     'opentable_support': 0,
#     'is_zomato_book_res': 0,
#     'mezzo_provider': 'OTHER',
#     'is_book_form_web_view': 0,
#     'book_form_web_view_url': '',
#     'book_again_url': '',
#     'thumb': 'https://b.zmtcdn.com/data/res_imagery/16777320_RESTAURANT_5bc92fcf35438e2404eb918270b2ea2c.jpg?fit=around%7C200%3A200&crop=200%3A200%3B%2A%2C%2A',
#     'user_rating': {'aggregate_rating': '4.5',
#      'rating_text': 'Excellent',
#      'rating_color': '3F7E00',
#      'votes': '969',
#      'has_fake_reviews': 0},
#     'photos_url': 'https://www.zomato.com/new-york-city/serendipity-3-upper-east-side/photos?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1#tabtop',
#     'menu_url': 'https://www.zomato.com/new-york-city/serendipity-3-upper-east-side/menu?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1&openSwipeBox=menu&showMinimal=1#tabtop',
#     'featured_image': 'https://b.zmtcdn.com/data/res_imagery/16777320_RESTAURANT_5bc92fcf35438e2404eb918270b2ea2c.jpg',
#     'has_online_delivery': 0,
#     'is_delivering_now': 0,
#     'has_fake_reviews': 0,
#     'include_bogo_offers': True,
#     'deeplink': 'zomato://restaurant/16777320',
#     'is_table_reservation_supported': 0,
#     'has_table_booking': 0,
#     'events_url': 'https://www.zomato.com/new-york-city/serendipity-3-upper-east-side/events#tabtop?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#     'establishment_types': []}},
#   {'restaurant': {'R': {'res_id': 16769089},
#     'apikey': '06e95084cb5d3426c57b51987827eb7d',
#     'id': '16769089',
#     'name': "John's Pizza of Times Square",
#     'url': 'https://www.zomato.com/new-york-city/johns-pizza-of-times-square-gramercy?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#     'location': {'address': '260 W 44th Street, New York 10036',
#      'locality': 'West 44th Street, Gramercy',
#      'city': 'New York City',
#      'city_id': 280,
#      'latitude': '40.7584111111',
#      'longitude': '-73.9882666667',
#      'zipcode': '10036',
#      'country_id': 216,
#      'locality_verbose': 'West 44th Street, Gramercy, New York City'},
#     'switch_to_order_menu': 0,
#     'cuisines': 'Italian, Pizza',
#     'average_cost_for_two': 40,
#     'price_range': 3,
#     'currency': '$',
#     'offers': [],
#     'opentable_support': 0,
#     'is_zomato_book_res': 0,
#     'mezzo_provider': 'OTHER',
#     'is_book_form_web_view': 0,
#     'book_form_web_view_url': '',
#     'book_again_url': '',
#     'thumb': 'https://b.zmtcdn.com/data/res_imagery/16769089_RESTAURANT_a7a23ba46bdbe76f7ffffc175679ede9_c.jpg?fit=around%7C200%3A200&crop=200%3A200%3B%2A%2C%2A',
#     'user_rating': {'aggregate_rating': '4.6',
#      'rating_text': 'Excellent',
#      'rating_color': '3F7E00',
#      'votes': '714',
#      'has_fake_reviews': 0},
#     'photos_url': 'https://www.zomato.com/new-york-city/johns-pizza-of-times-square-gramercy/photos?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1#tabtop',
#     'menu_url': 'https://www.zomato.com/new-york-city/johns-pizza-of-times-square-gramercy/menu?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1&openSwipeBox=menu&showMinimal=1#tabtop',
#     'featured_image': 'https://b.zmtcdn.com/data/res_imagery/16769089_RESTAURANT_a7a23ba46bdbe76f7ffffc175679ede9_c.jpg',
#     'has_online_delivery': 0,
#     'is_delivering_now': 0,
#     'has_fake_reviews': 0,
#     'include_bogo_offers': True,
#     'deeplink': 'zomato://restaurant/16769089',
#     'is_table_reservation_supported': 0,
#     'has_table_booking': 0,
#     'events_url': 'https://www.zomato.com/new-york-city/johns-pizza-of-times-square-gramercy/events#tabtop?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#     'establishment_types': []}},
#   {'restaurant': {'R': {'res_id': 16770626},
#     'apikey': '06e95084cb5d3426c57b51987827eb7d',
#     'id': '16770626',
#     'name': 'Le Bernardin',
#     'url': 'https://www.zomato.com/new-york-city/le-bernardin-gramercy?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#     'location': {'address': '155 W 51st Street, New York 10019',
#      'locality': 'Gramercy',
#      'city': 'New York City',
#      'city_id': 280,
#      'latitude': '40.7608027778',
#      'longitude': '-73.9819194444',
#      'zipcode': '10019',
#      'country_id': 216,
#      'locality_verbose': 'Gramercy'},
#     'switch_to_order_menu': 0,
#     'cuisines': 'French, Seafood',
#     'average_cost_for_two': 500,
#     'price_range': 4,
#     'currency': '$',
#     'offers': [],
#     'opentable_support': 0,
#     'is_zomato_book_res': 0,
#     'mezzo_provider': 'OTHER',
#     'is_book_form_web_view': 0,
#     'book_form_web_view_url': '',
#     'book_again_url': '',
#     'thumb': 'https://b.zmtcdn.com/data/pictures/6/16770626/a88c9e45fa431feacbd60f19a494165e.jpg?fit=around%7C200%3A200&crop=200%3A200%3B%2A%2C%2A',
#     'user_rating': {'aggregate_rating': '4.8',
#      'rating_text': 'Excellent',
#      'rating_color': '3F7E00',
#      'votes': '690',
#      'has_fake_reviews': 0},
#     'photos_url': 'https://www.zomato.com/new-york-city/le-bernardin-gramercy/photos?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1#tabtop',
#     'menu_url': 'https://www.zomato.com/new-york-city/le-bernardin-gramercy/menu?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1&openSwipeBox=menu&showMinimal=1#tabtop',
#     'featured_image': 'https://b.zmtcdn.com/data/pictures/6/16770626/a88c9e45fa431feacbd60f19a494165e.jpg',
#     'has_online_delivery': 0,
#     'is_delivering_now': 0,
#     'has_fake_reviews': 0,
#     'include_bogo_offers': True,
#     'deeplink': 'zomato://restaurant/16770626',
#     'is_table_reservation_supported': 0,
#     'has_table_booking': 0,
#     'events_url': 'https://www.zomato.com/new-york-city/le-bernardin-gramercy/events#tabtop?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#     'establishment_types': []}},
#   {'restaurant': {'R': {'res_id': 16781875},
#     'apikey': '06e95084cb5d3426c57b51987827eb7d',
#     'id': '16781875',
#     'name': 'Ippudo',
#     'url': 'https://www.zomato.com/new-york-city/ippudo-east-village?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#     'location': {'address': '65 4th Avenue, New York 10003',
#      'locality': 'East Village',
#      'city': 'New York City',
#      'city_id': 280,
#      'latitude': '40.7307361111',
#      'longitude': '-73.9906833333',
#      'zipcode': '10003',
#      'country_id': 216,
#      'locality_verbose': 'East Village'},
#     'switch_to_order_menu': 0,
#     'cuisines': 'Ramen',
#     'average_cost_for_two': 40,
#     'price_range': 3,
#     'currency': '$',
#     'offers': [],
#     'opentable_support': 0,
#     'is_zomato_book_res': 0,
#     'mezzo_provider': 'OTHER',
#     'is_book_form_web_view': 0,
#     'book_form_web_view_url': '',
#     'book_again_url': '',
#     'thumb': 'https://b.zmtcdn.com/data/pictures/5/16781875/1a72663426d6e780f6363b6b7da6d48b.png?fit=around%7C200%3A200&crop=200%3A200%3B%2A%2C%2A',
#     'user_rating': {'aggregate_rating': '4.9',
#      'rating_text': 'Excellent',
#      'rating_color': '3F7E00',
#      'votes': '921',
#      'has_fake_reviews': 0},
#     'photos_url': 'https://www.zomato.com/new-york-city/ippudo-east-village/photos?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1#tabtop',
#     'menu_url': 'https://www.zomato.com/new-york-city/ippudo-east-village/menu?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1&openSwipeBox=menu&showMinimal=1#tabtop',
#     'featured_image': 'https://b.zmtcdn.com/data/pictures/5/16781875/1a72663426d6e780f6363b6b7da6d48b.png?output-format=webp',
#     'has_online_delivery': 0,
#     'is_delivering_now': 0,
#     'has_fake_reviews': 0,
#     'include_bogo_offers': True,
#     'deeplink': 'zomato://restaurant/16781875',
#     'is_table_reservation_supported': 0,
#     'has_table_booking': 0,
#     'events_url': 'https://www.zomato.com/new-york-city/ippudo-east-village/events#tabtop?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#     'establishment_types': []}},
#   {'restaurant': {'R': {'res_id': 16765367},
#     'apikey': '06e95084cb5d3426c57b51987827eb7d',
#     'id': '16765367',
#     'name': 'Eleven Madison Park',
#     'url': 'https://www.zomato.com/new-york-city/eleven-madison-park-gramercy-flatiron?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#     'location': {'address': '11 Madison Avenue, New York 10010',
#      'locality': 'Gramercy-Flatiron',
#      'city': 'New York City',
#      'city_id': 280,
#      'latitude': '40.7415086000',
#      'longitude': '-73.9866285000',
#      'zipcode': '10010',
#      'country_id': 216,
#      'locality_verbose': 'Gramercy-Flatiron'},
#     'switch_to_order_menu': 0,
#     'cuisines': 'New American, French',
#     'average_cost_for_two': 650,
#     'price_range': 4,
#     'currency': '$',
#     'offers': [],
#     'opentable_support': 0,
#     'is_zomato_book_res': 0,
#     'mezzo_provider': 'OTHER',
#     'is_book_form_web_view': 0,
#     'book_form_web_view_url': '',
#     'book_again_url': '',
#     'thumb': 'https://b.zmtcdn.com/data/pictures/7/16765367/c118f3b0f7676bd605ae0355fc784b70.png?fit=around%7C200%3A200&crop=200%3A200%3B%2A%2C%2A',
#     'user_rating': {'aggregate_rating': '4.8',
#      'rating_text': 'Excellent',
#      'rating_color': '3F7E00',
#      'votes': '550',
#      'has_fake_reviews': 0},
#     'photos_url': 'https://www.zomato.com/new-york-city/eleven-madison-park-gramercy-flatiron/photos?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1#tabtop',
#     'menu_url': 'https://www.zomato.com/new-york-city/eleven-madison-park-gramercy-flatiron/menu?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1&openSwipeBox=menu&showMinimal=1#tabtop',
#     'featured_image': 'https://b.zmtcdn.com/data/pictures/7/16765367/c118f3b0f7676bd605ae0355fc784b70.png',
#     'has_online_delivery': 0,
#     'is_delivering_now': 0,
#     'has_fake_reviews': 0,
#     'include_bogo_offers': True,
#     'deeplink': 'zomato://restaurant/16765367',
#     'is_table_reservation_supported': 0,
#     'has_table_booking': 0,
#     'events_url': 'https://www.zomato.com/new-york-city/eleven-madison-park-gramercy-flatiron/events#tabtop?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#     'establishment_types': []}},
#   {'restaurant': {'R': {'res_id': 16775526},
#     'apikey': '06e95084cb5d3426c57b51987827eb7d',
#     'id': '16775526',
#     'name': 'Pommes Frites',
#     'url': 'https://www.zomato.com/new-york-city/pommes-frites-1-greenwich-village?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#     'location': {'address': '128 Macdougal Street, New York 10012',
#      'locality': 'Greenwich Village',
#      'city': 'New York City',
#      'city_id': 280,
#      'latitude': '40.7300310000',
#      'longitude': '-74.0001620000',
#      'zipcode': '10012',
#      'country_id': 216,
#      'locality_verbose': 'Greenwich Village'},
#     'switch_to_order_menu': 0,
#     'cuisines': 'European, Belgian',
#     'average_cost_for_two': 35,
#     'price_range': 2,
#     'currency': '$',
#     'offers': [],
#     'opentable_support': 0,
#     'is_zomato_book_res': 0,
#     'mezzo_provider': 'OTHER',
#     'is_book_form_web_view': 0,
#     'book_form_web_view_url': '',
#     'book_again_url': '',
#     'thumb': '',
#     'user_rating': {'aggregate_rating': '4.8',
#      'rating_text': 'Excellent',
#      'rating_color': '3F7E00',
#      'votes': '710',
#      'has_fake_reviews': 0},
#     'photos_url': 'https://www.zomato.com/new-york-city/pommes-frites-1-greenwich-village/photos?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1#tabtop',
#     'menu_url': 'https://www.zomato.com/new-york-city/pommes-frites-1-greenwich-village/menu?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1&openSwipeBox=menu&showMinimal=1#tabtop',
#     'featured_image': '',
#     'has_online_delivery': 0,
#     'is_delivering_now': 0,
#     'has_fake_reviews': 0,
#     'include_bogo_offers': True,
#     'deeplink': 'zomato://restaurant/16775526',
#     'is_table_reservation_supported': 0,
#     'has_table_booking': 0,
#     'events_url': 'https://www.zomato.com/new-york-city/pommes-frites-1-greenwich-village/events#tabtop?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#     'establishment_types': []}},
#   {'restaurant': {'R': {'res_id': 16776730},
#     'apikey': '06e95084cb5d3426c57b51987827eb7d',
#     'id': '16776730',
#     'name': 'Russ & Daughters',
#     'url': 'https://www.zomato.com/new-york-city/russ-daughters-lower-east-side?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#     'location': {'address': '179 E Houston Street, New York 10002',
#      'locality': 'Lower East Side',
#      'city': 'New York City',
#      'city_id': 280,
#      'latitude': '40.7227361111',
#      'longitude': '-73.9882361111',
#      'zipcode': '10002',
#      'country_id': 216,
#      'locality_verbose': 'Lower East Side'},
#     'switch_to_order_menu': 0,
#     'cuisines': 'Seafood, Bagels',
#     'average_cost_for_two': 25,
#     'price_range': 2,
#     'currency': '$',
#     'offers': [],
#     'opentable_support': 0,
#     'is_zomato_book_res': 0,
#     'mezzo_provider': 'OTHER',
#     'is_book_form_web_view': 0,
#     'book_form_web_view_url': '',
#     'book_again_url': '',
#     'thumb': 'https://b.zmtcdn.com/data/pictures/0/16776730/49e617fc653ad30851526dfefc8cef86.jpg?fit=around%7C200%3A200&crop=200%3A200%3B%2A%2C%2A',
#     'user_rating': {'aggregate_rating': '4.8',
#      'rating_text': 'Excellent',
#      'rating_color': '3F7E00',
#      'votes': '253',
#      'has_fake_reviews': 0},
#     'photos_url': 'https://www.zomato.com/new-york-city/russ-daughters-lower-east-side/photos?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1#tabtop',
#     'menu_url': 'https://www.zomato.com/new-york-city/russ-daughters-lower-east-side/menu?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1&openSwipeBox=menu&showMinimal=1#tabtop',
#     'featured_image': 'https://b.zmtcdn.com/data/pictures/0/16776730/49e617fc653ad30851526dfefc8cef86.jpg',
#     'has_online_delivery': 0,
#     'is_delivering_now': 0,
#     'has_fake_reviews': 0,
#     'include_bogo_offers': True,
#     'deeplink': 'zomato://restaurant/16776730',
#     'is_table_reservation_supported': 0,
#     'has_table_booking': 0,
#     'events_url': 'https://www.zomato.com/new-york-city/russ-daughters-lower-east-side/events#tabtop?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#     'establishment_types': []}},
#   {'restaurant': {'R': {'res_id': 16777384},
#     'apikey': '06e95084cb5d3426c57b51987827eb7d',
#     'id': '16777384',
#     'name': 'Shake Shack',
#     'url': 'https://www.zomato.com/new-york-city/shake-shack-gramercy-flatiron?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#     'location': {'address': 'Madison Square Park, 23rd & Madison, New York 10010',
#      'locality': 'Gramercy-Flatiron',
#      'city': 'New York City',
#      'city_id': 280,
#      'latitude': '40.7408681000',
#      'longitude': '-73.9879841000',
#      'zipcode': '10010',
#      'country_id': 216,
#      'locality_verbose': 'Gramercy-Flatiron'},
#     'switch_to_order_menu': 0,
#     'cuisines': 'American, Burger',
#     'average_cost_for_two': 30,
#     'price_range': 2,
#     'currency': '$',
#     'offers': [],
#     'opentable_support': 0,
#     'is_zomato_book_res': 0,
#     'mezzo_provider': 'OTHER',
#     'is_book_form_web_view': 0,
#     'book_form_web_view_url': '',
#     'book_again_url': '',
#     'thumb': 'https://b.zmtcdn.com/data/pictures/4/16777384/2a989275f117f6bf1f63919c66cbc2cc.jpg?fit=around%7C200%3A200&crop=200%3A200%3B%2A%2C%2A',
#     'user_rating': {'aggregate_rating': '4.9',
#      'rating_text': 'Excellent',
#      'rating_color': '3F7E00',
#      'votes': '1634',
#      'has_fake_reviews': 0},
#     'photos_url': 'https://www.zomato.com/new-york-city/shake-shack-gramercy-flatiron/photos?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1#tabtop',
#     'menu_url': 'https://www.zomato.com/new-york-city/shake-shack-gramercy-flatiron/menu?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1&openSwipeBox=menu&showMinimal=1#tabtop',
#     'featured_image': 'https://b.zmtcdn.com/data/pictures/4/16777384/2a989275f117f6bf1f63919c66cbc2cc.jpg',
#     'has_online_delivery': 0,
#     'is_delivering_now': 0,
#     'has_fake_reviews': 0,
#     'include_bogo_offers': True,
#     'deeplink': 'zomato://restaurant/16777384',
#     'is_table_reservation_supported': 0,
#     'has_table_booking': 0,
#     'events_url': 'https://www.zomato.com/new-york-city/shake-shack-gramercy-flatiron/events#tabtop?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#     'establishment_types': []}},
#   {'restaurant': {'R': {'res_id': 16761868},
#     'apikey': '06e95084cb5d3426c57b51987827eb7d',
#     'id': '16761868',
#     'name': 'Cafeteria',
#     'url': 'https://www.zomato.com/new-york-city/cafeteria-chelsea-manhattan?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#     'location': {'address': '119 7th Avenue 10011',
#      'locality': 'Chelsea, Manhattan',
#      'city': 'New York City',
#      'city_id': 280,
#      'latitude': '40.7407100000',
#      'longitude': '-73.9980000000',
#      'zipcode': '10011',
#      'country_id': 216,
#      'locality_verbose': 'Chelsea, Manhattan'},
#     'switch_to_order_menu': 0,
#     'cuisines': 'American',
#     'average_cost_for_two': 75,
#     'price_range': 4,
#     'currency': '$',
#     'offers': [],
#     'opentable_support': 0,
#     'is_zomato_book_res': 0,
#     'mezzo_provider': 'OTHER',
#     'is_book_form_web_view': 0,
#     'book_form_web_view_url': '',
#     'book_again_url': '',
#     'thumb': 'https://b.zmtcdn.com/data/pictures/chains/8/16761868/bd779e8a55d1e38bf489a4b373099cf1.jpg?fit=around%7C200%3A200&crop=200%3A200%3B%2A%2C%2A',
#     'user_rating': {'aggregate_rating': '4.4',
#      'rating_text': 'Very Good',
#      'rating_color': '5BA829',
#      'votes': '634',
#      'has_fake_reviews': 0},
#     'photos_url': 'https://www.zomato.com/new-york-city/cafeteria-chelsea-manhattan/photos?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1#tabtop',
#     'menu_url': 'https://www.zomato.com/new-york-city/cafeteria-chelsea-manhattan/menu?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1&openSwipeBox=menu&showMinimal=1#tabtop',
#     'featured_image': 'https://b.zmtcdn.com/data/pictures/chains/8/16761868/bd779e8a55d1e38bf489a4b373099cf1.jpg',
#     'has_online_delivery': 0,
#     'is_delivering_now': 0,
#     'has_fake_reviews': 0,
#     'include_bogo_offers': True,
#     'deeplink': 'zomato://restaurant/16761868',
#     'is_table_reservation_supported': 0,
#     'has_table_booking': 0,
#     'events_url': 'https://www.zomato.com/new-york-city/cafeteria-chelsea-manhattan/events#tabtop?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#     'establishment_types': []}},
#   {'restaurant': {'R': {'res_id': 16767139},
#     'apikey': '06e95084cb5d3426c57b51987827eb7d',
#     'id': '16767139',
#     'name': 'Gramercy Tavern',
#     'url': 'https://www.zomato.com/new-york-city/gramercy-tavern-gramercy-flatiron?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#     'location': {'address': '42 E 20th Street 10003',
#      'locality': 'East 20th Street, Gramercy-Flatiron',
#      'city': 'New York City',
#      'city_id': 280,
#      'latitude': '40.7387166667',
#      'longitude': '-73.9883888889',
#      'zipcode': '10003',
#      'country_id': 216,
#      'locality_verbose': 'East 20th Street, Gramercy-Flatiron, New York City'},
#     'switch_to_order_menu': 0,
#     'cuisines': 'American',
#     'average_cost_for_two': 200,
#     'price_range': 4,
#     'currency': '$',
#     'offers': [],
#     'opentable_support': 0,
#     'is_zomato_book_res': 0,
#     'mezzo_provider': 'OTHER',
#     'is_book_form_web_view': 0,
#     'book_form_web_view_url': '',
#     'book_again_url': '',
#     'thumb': 'https://b.zmtcdn.com/data/pictures/9/16767139/8e3fae144133ba709852d6eec7280397.jpg?fit=around%7C200%3A200&crop=200%3A200%3B%2A%2C%2A',
#     'user_rating': {'aggregate_rating': '4.5',
#      'rating_text': 'Excellent',
#      'rating_color': '3F7E00',
#      'votes': '959',
#      'has_fake_reviews': 0},
#     'photos_url': 'https://www.zomato.com/new-york-city/gramercy-tavern-gramercy-flatiron/photos?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1#tabtop',
#     'menu_url': 'https://www.zomato.com/new-york-city/gramercy-tavern-gramercy-flatiron/menu?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1&openSwipeBox=menu&showMinimal=1#tabtop',
#     'featured_image': 'https://b.zmtcdn.com/data/pictures/9/16767139/8e3fae144133ba709852d6eec7280397.jpg',
#     'has_online_delivery': 0,
#     'is_delivering_now': 0,
#     'has_fake_reviews': 0,
#     'include_bogo_offers': True,
#     'deeplink': 'zomato://restaurant/16767139',
#     'is_table_reservation_supported': 0,
#     'has_table_booking': 0,
#     'events_url': 'https://www.zomato.com/new-york-city/gramercy-tavern-gramercy-flatiron/events#tabtop?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#     'establishment_types': []}},
#   {'restaurant': {'R': {'res_id': 16761402},
#     'apikey': '06e95084cb5d3426c57b51987827eb7d',
#     'id': '16761402',
#     'name': 'Burger Joint',
#     'url': 'https://www.zomato.com/new-york-city/burger-joint-midtown?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#     'location': {'address': '119 West 56th Street 10019',
#      'locality': 'Midtown',
#      'city': 'New York City',
#      'city_id': 280,
#      'latitude': '40.7639500000',
#      'longitude': '-73.9781800000',
#      'zipcode': '10019',
#      'country_id': 216,
#      'locality_verbose': 'Midtown'},
#     'switch_to_order_menu': 0,
#     'cuisines': 'Burger',
#     'average_cost_for_two': 25,
#     'price_range': 2,
#     'currency': '$',
#     'offers': [],
#     'opentable_support': 0,
#     'is_zomato_book_res': 0,
#     'mezzo_provider': 'OTHER',
#     'is_book_form_web_view': 0,
#     'book_form_web_view_url': '',
#     'book_again_url': '',
#     'thumb': 'https://b.zmtcdn.com/data/pictures/chains/2/16761402/beda9e63e3230d51c78f589d45e372cf.jpg?fit=around%7C200%3A200&crop=200%3A200%3B%2A%2C%2A',
#     'user_rating': {'aggregate_rating': '4.8',
#      'rating_text': 'Excellent',
#      'rating_color': '3F7E00',
#      'votes': '870',
#      'has_fake_reviews': 0},
#     'photos_url': 'https://www.zomato.com/new-york-city/burger-joint-midtown/photos?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1#tabtop',
#     'menu_url': 'https://www.zomato.com/new-york-city/burger-joint-midtown/menu?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1&openSwipeBox=menu&showMinimal=1#tabtop',
#     'featured_image': 'https://b.zmtcdn.com/data/pictures/chains/2/16761402/beda9e63e3230d51c78f589d45e372cf.jpg',
#     'has_online_delivery': 0,
#     'is_delivering_now': 0,
#     'has_fake_reviews': 0,
#     'include_bogo_offers': True,
#     'deeplink': 'zomato://restaurant/16761402',
#     'is_table_reservation_supported': 0,
#     'has_table_booking': 0,
#     'events_url': 'https://www.zomato.com/new-york-city/burger-joint-midtown/events#tabtop?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#     'establishment_types': []}},
#   {'restaurant': {'R': {'res_id': 16783998},
#     'apikey': '06e95084cb5d3426c57b51987827eb7d',
#     'id': '16783998',
#     'name': 'The Halal Guys',
#     'url': 'https://www.zomato.com/the-halal-guys-food-truck?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#     'location': {'address': 'W 53rd Street & 7th Ave New York 10019',
#      'locality': 'Midtown',
#      'city': 'New York City',
#      'city_id': 280,
#      'latitude': '40.7617884000',
#      'longitude': '-73.9790839000',
#      'zipcode': '10019',
#      'country_id': 216,
#      'locality_verbose': 'Midtown'},
#     'switch_to_order_menu': 0,
#     'cuisines': 'Middle Eastern, Moroccan',
#     'average_cost_for_two': 25,
#     'price_range': 2,
#     'currency': '$',
#     'offers': [],
#     'opentable_support': 0,
#     'is_zomato_book_res': 0,
#     'mezzo_provider': 'OTHER',
#     'is_book_form_web_view': 0,
#     'book_form_web_view_url': '',
#     'book_again_url': '',
#     'thumb': 'https://b.zmtcdn.com/data/reviews_photos/6b0/bdee283500e51cc7ae84c496257086b0_1532961119.jpg?fit=around%7C200%3A200&crop=200%3A200%3B%2A%2C%2A',
#     'user_rating': {'aggregate_rating': '4.9',
#      'rating_text': 'Excellent',
#      'rating_color': '3F7E00',
#      'votes': '456',
#      'has_fake_reviews': 0},
#     'photos_url': 'https://www.zomato.com/the-halal-guys-food-truck/photos?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1#tabtop',
#     'menu_url': 'https://www.zomato.com/the-halal-guys-food-truck/menu?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1&openSwipeBox=menu&showMinimal=1#tabtop',
#     'featured_image': 'https://b.zmtcdn.com/data/reviews_photos/6b0/bdee283500e51cc7ae84c496257086b0_1532961119.jpg?output-format=webp',
#     'has_online_delivery': 0,
#     'is_delivering_now': 0,
#     'has_fake_reviews': 0,
#     'include_bogo_offers': True,
#     'deeplink': 'zomato://restaurant/16783998',
#     'is_table_reservation_supported': 0,
#     'has_table_booking': 0,
#     'events_url': 'https://www.zomato.com/the-halal-guys-food-truck/events#tabtop?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#     'establishment_types': []}}]}

# %%
# Lunch
headers= {
    "user-key":Key,
    "Accept": "application/json" 
}
params= {
    "category": 2,
    "entity_id": 280,
    "entity_type": "city",
}

# search
dine_results = requests.get(url=url+"search?",headers=headers,params=params)

# %%
dine_results.json()
# Out:
# {'results_found': 21320,
#  'results_start': 0,
#  'results_shown': 20,
#  'restaurants': [{'restaurant': {'R': {'res_id': 16771079},
#     'apikey': '06e95084cb5d3426c57b51987827eb7d',
#     'id': '16771079',
#     'name': "Lombardi's Pizza",
#     'url': 'https://www.zomato.com/new-york-city/lombardis-pizza-lower-east-side?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#     'location': {'address': '32 Spring Street, New York 10012',
#      'locality': 'Spring Street, Lower East Side',
#      'city': 'New York City',
#      'city_id': 280,
#      'latitude': '40.7216750000',
#      'longitude': '-73.9955888889',
#      'zipcode': '10012',
#      'country_id': 216,
#      'locality_verbose': 'Spring Street, Lower East Side, New York City'},
#     'switch_to_order_menu': 0,
#     'cuisines': 'Pizza, Italian',
#     'average_cost_for_two': 50,
#     'price_range': 3,
#     'currency': '$',
#     'offers': [],
#     'opentable_support': 0,
#     'is_zomato_book_res': 0,
#     'mezzo_provider': 'OTHER',
#     'is_book_form_web_view': 0,
#     'book_form_web_view_url': '',
#     'book_again_url': '',
#     'thumb': 'https://b.zmtcdn.com/data/res_imagery/16771079_RESTAURANT_da60c9abb32fa64cddc148a2795ae43c_c.jpg?fit=around%7C200%3A200&crop=200%3A200%3B%2A%2C%2A',
#     'user_rating': {'aggregate_rating': '4.9',
#      'rating_text': 'Excellent',
#      'rating_color': '3F7E00',
#      'votes': '1471',
#      'has_fake_reviews': 0},
#     'photos_url': 'https://www.zomato.com/new-york-city/lombardis-pizza-lower-east-side/photos?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1#tabtop',
#     'menu_url': 'https://www.zomato.com/new-york-city/lombardis-pizza-lower-east-side/menu?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1&openSwipeBox=menu&showMinimal=1#tabtop',
#     'featured_image': 'https://b.zmtcdn.com/data/res_imagery/16771079_RESTAURANT_da60c9abb32fa64cddc148a2795ae43c_c.jpg',
#     'has_online_delivery': 0,
#     'is_delivering_now': 0,
#     'has_fake_reviews': 0,
#     'include_bogo_offers': True,
#     'deeplink': 'zomato://restaurant/16771079',
#     'is_table_reservation_supported': 0,
#     'has_table_booking': 0,
#     'events_url': 'https://www.zomato.com/new-york-city/lombardis-pizza-lower-east-side/events#tabtop?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#     'establishment_types': []}},
#   {'restaurant': {'R': {'res_id': 16769546},
#     'apikey': '06e95084cb5d3426c57b51987827eb7d',
#     'id': '16769546',
#     'name': "Katz's Delicatessen",
#     'url': 'https://www.zomato.com/new-york-city/katzs-delicatessen-lower-east-side?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#     'location': {'address': '205 East Houston Street, New York 10002',
#      'locality': 'Lower East Side',
#      'city': 'New York City',
#      'city_id': 280,
#      'latitude': '40.7223277778',
#      'longitude': '-73.9873500000',
#      'zipcode': '10002',
#      'country_id': 216,
#      'locality_verbose': 'Lower East Side'},
#     'switch_to_order_menu': 0,
#     'cuisines': 'Sandwich',
#     'average_cost_for_two': 30,
#     'price_range': 2,
#     'currency': '$',
#     'offers': [],
#     'opentable_support': 0,
#     'is_zomato_book_res': 0,
#     'mezzo_provider': 'OTHER',
#     'is_book_form_web_view': 0,
#     'book_form_web_view_url': '',
#     'book_again_url': '',
#     'thumb': 'https://b.zmtcdn.com/data/pictures/6/16769546/48ab9901ddf191d13ade07221b43ba93.jpg?fit=around%7C200%3A200&crop=200%3A200%3B%2A%2C%2A',
#     'user_rating': {'aggregate_rating': '4.9',
#      'rating_text': 'Excellent',
#      'rating_color': '3F7E00',
#      'votes': '2501',
#      'has_fake_reviews': 0},
#     'photos_url': 'https://www.zomato.com/new-york-city/katzs-delicatessen-lower-east-side/photos?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1#tabtop',
#     'menu_url': 'https://www.zomato.com/new-york-city/katzs-delicatessen-lower-east-side/menu?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1&openSwipeBox=menu&showMinimal=1#tabtop',
#     'featured_image': 'https://b.zmtcdn.com/data/pictures/6/16769546/48ab9901ddf191d13ade07221b43ba93.jpg',
#     'has_online_delivery': 0,
#     'is_delivering_now': 0,
#     'has_fake_reviews': 0,
#     'include_bogo_offers': True,
#     'deeplink': 'zomato://restaurant/16769546',
#     'is_table_reservation_supported': 0,
#     'has_table_booking': 0,
#     'events_url': 'https://www.zomato.com/new-york-city/katzs-delicatessen-lower-east-side/events#tabtop?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#     'establishment_types': []}},
#   {'restaurant': {'R': {'res_id': 16767332},
#     'apikey': '06e95084cb5d3426c57b51987827eb7d',
#     'id': '16767332',
#     'name': "Grimaldi's Pizzeria",
#     'url': 'https://www.zomato.com/new-york-city/grimaldis-pizzeria-dumbo?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#     'location': {'address': '1 Front Street, Brooklyn 11201',
#      'locality': 'Front Street, DUMBO',
#      'city': 'New York City',
#      'city_id': 280,
#      'latitude': '40.7025138889',
#      'longitude': '-73.9932722222',
#      'zipcode': '11201',
#      'country_id': 216,
#      'locality_verbose': 'Front Street, DUMBO, New York City'},
#     'switch_to_order_menu': 0,
#     'cuisines': 'Pizza, Italian',
#     'average_cost_for_two': 50,
#     'price_range': 3,
#     'currency': '$',
#     'offers': [],
#     'opentable_support': 0,
#     'is_zomato_book_res': 0,
#     'mezzo_provider': 'OTHER',
#     'is_book_form_web_view': 0,
#     'book_form_web_view_url': '',
#     'book_again_url': '',
#     'thumb': 'https://b.zmtcdn.com/data/pictures/chains/2/16767332/fa6705919261e9c27ae46737d56a0faa.jpg?fit=around%7C200%3A200&crop=200%3A200%3B%2A%2C%2A',
#     'user_rating': {'aggregate_rating': '4.6',
#      'rating_text': 'Excellent',
#      'rating_color': '3F7E00',
#      'votes': '945',
#      'has_fake_reviews': 0},
#     'photos_url': 'https://www.zomato.com/new-york-city/grimaldis-pizzeria-dumbo/photos?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1#tabtop',
#     'menu_url': 'https://www.zomato.com/new-york-city/grimaldis-pizzeria-dumbo/menu?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1&openSwipeBox=menu&showMinimal=1#tabtop',
#     'featured_image': 'https://b.zmtcdn.com/data/pictures/chains/2/16767332/fa6705919261e9c27ae46737d56a0faa.jpg',
#     'has_online_delivery': 0,
#     'is_delivering_now': 0,
#     'has_fake_reviews': 0,
#     'include_bogo_offers': True,
#     'deeplink': 'zomato://restaurant/16767332',
#     'is_table_reservation_supported': 0,
#     'has_table_booking': 0,
#     'events_url': 'https://www.zomato.com/new-york-city/grimaldis-pizzeria-dumbo/events#tabtop?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#     'establishment_types': []}},
#   {'restaurant': {'R': {'res_id': 16780467},
#     'apikey': '06e95084cb5d3426c57b51987827eb7d',
#     'id': '16780467',
#     'name': 'Veselka',
#     'url': 'https://www.zomato.com/new-york-city/veselka-east-village?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#     'location': {'address': '144 2nd Avenue 10003',
#      'locality': 'East Village',
#      'city': 'New York City',
#      'city_id': 280,
#      'latitude': '40.7287300000',
#      'longitude': '-73.9870800000',
#      'zipcode': '10003',
#      'country_id': 216,
#      'locality_verbose': 'East Village'},
#     'switch_to_order_menu': 0,
#     'cuisines': 'Ukrainian',
#     'average_cost_for_two': 40,
#     'price_range': 3,
#     'currency': '$',
#     'offers': [],
#     'opentable_support': 0,
#     'is_zomato_book_res': 0,
#     'mezzo_provider': 'OTHER',
#     'is_book_form_web_view': 0,
#     'book_form_web_view_url': '',
#     'book_again_url': '',
#     'thumb': 'https://b.zmtcdn.com/data/pictures/7/16780467/95079d815c89a8bfafa31e73f81ce3ba.jpg?fit=around%7C200%3A200&crop=200%3A200%3B%2A%2C%2A',
#     'user_rating': {'aggregate_rating': '4.6',
#      'rating_text': 'Excellent',
#      'rating_color': '3F7E00',
#      'votes': '699',
#      'has_fake_reviews': 0},
#     'photos_url': 'https://www.zomato.com/new-york-city/veselka-east-village/photos?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1#tabtop',
#     'menu_url': 'https://www.zomato.com/new-york-city/veselka-east-village/menu?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1&openSwipeBox=menu&showMinimal=1#tabtop',
#     'featured_image': 'https://b.zmtcdn.com/data/pictures/7/16780467/95079d815c89a8bfafa31e73f81ce3ba.jpg',
#     'has_online_delivery': 0,
#     'is_delivering_now': 0,
#     'has_fake_reviews': 0,
#     'include_bogo_offers': True,
#     'deeplink': 'zomato://restaurant/16780467',
#     'is_table_reservation_supported': 0,
#     'has_table_booking': 0,
#     'events_url': 'https://www.zomato.com/new-york-city/veselka-east-village/events#tabtop?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#     'establishment_types': []}},
#   {'restaurant': {'R': {'res_id': 16779248},
#     'apikey': '06e95084cb5d3426c57b51987827eb7d',
#     'id': '16779248',
#     'name': 'Tao',
#     'url': 'https://www.zomato.com/new-york-city/tao-midtown?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#     'location': {'address': '42 E 58th Street, New York 10022',
#      'locality': 'Midtown',
#      'city': 'New York City',
#      'city_id': 280,
#      'latitude': '40.7627111111',
#      'longitude': '-73.9713750000',
#      'zipcode': '10022',
#      'country_id': 216,
#      'locality_verbose': 'Midtown'},
#     'switch_to_order_menu': 0,
#     'cuisines': 'Asian, Chinese',
#     'average_cost_for_two': 150,
#     'price_range': 4,
#     'currency': '$',
#     'offers': [],
#     'opentable_support': 0,
#     'is_zomato_book_res': 0,
#     'mezzo_provider': 'OTHER',
#     'is_book_form_web_view': 0,
#     'book_form_web_view_url': '',
#     'book_again_url': '',
#     'thumb': 'https://b.zmtcdn.com/data/res_imagery/16779248_RESTAURANT_68d0ceba78997b23ff011573ee029f13_c.jpg?fit=around%7C200%3A200&crop=200%3A200%3B%2A%2C%2A',
#     'user_rating': {'aggregate_rating': '4.4',
#      'rating_text': 'Very Good',
#      'rating_color': '5BA829',
#      'votes': '699',
#      'has_fake_reviews': 0},
#     'photos_url': 'https://www.zomato.com/new-york-city/tao-midtown/photos?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1#tabtop',
#     'menu_url': 'https://www.zomato.com/new-york-city/tao-midtown/menu?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1&openSwipeBox=menu&showMinimal=1#tabtop',
#     'featured_image': 'https://b.zmtcdn.com/data/res_imagery/16779248_RESTAURANT_68d0ceba78997b23ff011573ee029f13_c.jpg',
#     'has_online_delivery': 0,
#     'is_delivering_now': 0,
#     'has_fake_reviews': 0,
#     'include_bogo_offers': True,
#     'deeplink': 'zomato://restaurant/16779248',
#     'is_table_reservation_supported': 0,
#     'has_table_booking': 0,
#     'events_url': 'https://www.zomato.com/new-york-city/tao-midtown/events#tabtop?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#     'establishment_types': []}},
#   {'restaurant': {'R': {'res_id': 16760100},
#     'apikey': '06e95084cb5d3426c57b51987827eb7d',
#     'id': '16760100',
#     'name': 'Balthazar',
#     'url': 'https://www.zomato.com/new-york-city/balthazar-soho?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#     'location': {'address': '80 Spring Street 10012',
#      'locality': 'Soho',
#      'city': 'New York City',
#      'city_id': 280,
#      'latitude': '40.7225900000',
#      'longitude': '-73.9980500000',
#      'zipcode': '10012',
#      'country_id': 216,
#      'locality_verbose': 'Soho'},
#     'switch_to_order_menu': 0,
#     'cuisines': 'French, Seafood, Bakery',
#     'average_cost_for_two': 140,
#     'price_range': 4,
#     'currency': '$',
#     'offers': [],
#     'opentable_support': 0,
#     'is_zomato_book_res': 0,
#     'mezzo_provider': 'OTHER',
#     'is_book_form_web_view': 0,
#     'book_form_web_view_url': '',
#     'book_again_url': '',
#     'thumb': 'https://b.zmtcdn.com/data/pictures/0/16760100/2cee8640b74a1e53fde146c9c90f5213.png?fit=around%7C200%3A200&crop=200%3A200%3B%2A%2C%2A',
#     'user_rating': {'aggregate_rating': '4.6',
#      'rating_text': 'Excellent',
#      'rating_color': '3F7E00',
#      'votes': '1861',
#      'has_fake_reviews': 0},
#     'photos_url': 'https://www.zomato.com/new-york-city/balthazar-soho/photos?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1#tabtop',
#     'menu_url': 'https://www.zomato.com/new-york-city/balthazar-soho/menu?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1&openSwipeBox=menu&showMinimal=1#tabtop',
#     'featured_image': 'https://b.zmtcdn.com/data/pictures/0/16760100/2cee8640b74a1e53fde146c9c90f5213.png',
#     'has_online_delivery': 0,
#     'is_delivering_now': 0,
#     'has_fake_reviews': 0,
#     'include_bogo_offers': True,
#     'deeplink': 'zomato://restaurant/16760100',
#     'is_table_reservation_supported': 0,
#     'has_table_booking': 0,
#     'events_url': 'https://www.zomato.com/new-york-city/balthazar-soho/events#tabtop?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#     'establishment_types': []}},
#   {'restaurant': {'R': {'res_id': 16775039},
#     'apikey': '06e95084cb5d3426c57b51987827eb7d',
#     'id': '16775039',
#     'name': 'Peter Luger Steak House',
#     'url': 'https://www.zomato.com/new-york-city/peter-luger-steak-house-south-side?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#     'location': {'address': '178 Broadway, Brooklyn 11211',
#      'locality': 'South Side',
#      'city': 'New York City',
#      'city_id': 280,
#      'latitude': '40.7098777778',
#      'longitude': '-73.9623416667',
#      'zipcode': '11211',
#      'country_id': 216,
#      'locality_verbose': 'South Side'},
#     'switch_to_order_menu': 0,
#     'cuisines': 'Steak, American, German, Burger',
#     'average_cost_for_two': 150,
#     'price_range': 4,
#     'currency': '$',
#     'offers': [],
#     'opentable_support': 0,
#     'is_zomato_book_res': 0,
#     'mezzo_provider': 'OTHER',
#     'is_book_form_web_view': 0,
#     'book_form_web_view_url': '',
#     'book_again_url': '',
#     'thumb': 'https://b.zmtcdn.com/data/reviews_photos/ea9/ed66f37a5492836605ec71582db68ea9_1441919144.jpg?fit=around%7C200%3A200&crop=200%3A200%3B%2A%2C%2A',
#     'user_rating': {'aggregate_rating': '4.7',
#      'rating_text': 'Excellent',
#      'rating_color': '3F7E00',
#      'votes': '1115',
#      'has_fake_reviews': 0},
#     'photos_url': 'https://www.zomato.com/new-york-city/peter-luger-steak-house-south-side/photos?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1#tabtop',
#     'menu_url': 'https://www.zomato.com/new-york-city/peter-luger-steak-house-south-side/menu?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1&openSwipeBox=menu&showMinimal=1#tabtop',
#     'featured_image': 'https://b.zmtcdn.com/data/reviews_photos/ea9/ed66f37a5492836605ec71582db68ea9_1441919144.jpg',
#     'has_online_delivery': 0,
#     'is_delivering_now': 0,
#     'has_fake_reviews': 0,
#     'include_bogo_offers': True,
#     'deeplink': 'zomato://restaurant/16775039',
#     'is_table_reservation_supported': 0,
#     'has_table_booking': 0,
#     'events_url': 'https://www.zomato.com/new-york-city/peter-luger-steak-house-south-side/events#tabtop?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#     'establishment_types': []}},
#   {'restaurant': {'R': {'res_id': 16762160},
#     'apikey': '06e95084cb5d3426c57b51987827eb7d',
#     'id': '16762160',
#     'name': "Carmine's Italian Restaurant",
#     'url': 'https://www.zomato.com/new-york-city/carmines-italian-restaurant-gramercy?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#     'location': {'address': '200 West 44th Street, btwn Broadway & 8th Avenue 10036',
#      'locality': 'West 44th Street, Gramercy',
#      'city': 'New York City',
#      'city_id': 280,
#      'latitude': '40.7579000000',
#      'longitude': '-73.9875700000',
#      'zipcode': '10036',
#      'country_id': 216,
#      'locality_verbose': 'West 44th Street, Gramercy, New York City'},
#     'switch_to_order_menu': 0,
#     'cuisines': 'Italian, Southern',
#     'average_cost_for_two': 100,
#     'price_range': 4,
#     'currency': '$',
#     'offers': [],
#     'opentable_support': 0,
#     'is_zomato_book_res': 0,
#     'mezzo_provider': 'OTHER',
#     'is_book_form_web_view': 0,
#     'book_form_web_view_url': '',
#     'book_again_url': '',
#     'thumb': 'https://b.zmtcdn.com/data/pictures/0/16762160/7f5654c601548a24af81beb345d99f1b.jpg?fit=around%7C200%3A200&crop=200%3A200%3B%2A%2C%2A',
#     'user_rating': {'aggregate_rating': '4.8',
#      'rating_text': 'Excellent',
#      'rating_color': '3F7E00',
#      'votes': '1028',
#      'has_fake_reviews': 0},
#     'photos_url': 'https://www.zomato.com/new-york-city/carmines-italian-restaurant-gramercy/photos?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1#tabtop',
#     'menu_url': 'https://www.zomato.com/new-york-city/carmines-italian-restaurant-gramercy/menu?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1&openSwipeBox=menu&showMinimal=1#tabtop',
#     'featured_image': 'https://b.zmtcdn.com/data/pictures/0/16762160/7f5654c601548a24af81beb345d99f1b.jpg?output-format=webp',
#     'has_online_delivery': 0,
#     'is_delivering_now': 0,
#     'has_fake_reviews': 0,
#     'include_bogo_offers': True,
#     'deeplink': 'zomato://restaurant/16762160',
#     'is_table_reservation_supported': 0,
#     'has_table_booking': 0,
#     'events_url': 'https://www.zomato.com/new-york-city/carmines-italian-restaurant-gramercy/events#tabtop?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#     'establishment_types': []}},
#   {'restaurant': {'R': {'res_id': 16777320},
#     'apikey': '06e95084cb5d3426c57b51987827eb7d',
#     'id': '16777320',
#     'name': 'Serendipity 3',
#     'url': 'https://www.zomato.com/new-york-city/serendipity-3-upper-east-side?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#     'location': {'address': '225 East 60th Street 10022',
#      'locality': 'Upper East Side',
#      'city': 'New York City',
#      'city_id': 280,
#      'latitude': '40.7618668000',
#      'longitude': '-73.9649001000',
#      'zipcode': '10022',
#      'country_id': 216,
#      'locality_verbose': 'Upper East Side'},
#     'switch_to_order_menu': 0,
#     'cuisines': 'American, Desserts',
#     'average_cost_for_two': 75,
#     'price_range': 4,
#     'currency': '$',
#     'offers': [],
#     'opentable_support': 0,
#     'is_zomato_book_res': 0,
#     'mezzo_provider': 'OTHER',
#     'is_book_form_web_view': 0,
#     'book_form_web_view_url': '',
#     'book_again_url': '',
#     'thumb': 'https://b.zmtcdn.com/data/res_imagery/16777320_RESTAURANT_5bc92fcf35438e2404eb918270b2ea2c.jpg?fit=around%7C200%3A200&crop=200%3A200%3B%2A%2C%2A',
#     'user_rating': {'aggregate_rating': '4.5',
#      'rating_text': 'Excellent',
#      'rating_color': '3F7E00',
#      'votes': '969',
#      'has_fake_reviews': 0},
#     'photos_url': 'https://www.zomato.com/new-york-city/serendipity-3-upper-east-side/photos?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1#tabtop',
#     'menu_url': 'https://www.zomato.com/new-york-city/serendipity-3-upper-east-side/menu?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1&openSwipeBox=menu&showMinimal=1#tabtop',
#     'featured_image': 'https://b.zmtcdn.com/data/res_imagery/16777320_RESTAURANT_5bc92fcf35438e2404eb918270b2ea2c.jpg',
#     'has_online_delivery': 0,
#     'is_delivering_now': 0,
#     'has_fake_reviews': 0,
#     'include_bogo_offers': True,
#     'deeplink': 'zomato://restaurant/16777320',
#     'is_table_reservation_supported': 0,
#     'has_table_booking': 0,
#     'events_url': 'https://www.zomato.com/new-york-city/serendipity-3-upper-east-side/events#tabtop?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#     'establishment_types': []}},
#   {'restaurant': {'R': {'res_id': 16769089},
#     'apikey': '06e95084cb5d3426c57b51987827eb7d',
#     'id': '16769089',
#     'name': "John's Pizza of Times Square",
#     'url': 'https://www.zomato.com/new-york-city/johns-pizza-of-times-square-gramercy?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#     'location': {'address': '260 W 44th Street, New York 10036',
#      'locality': 'West 44th Street, Gramercy',
#      'city': 'New York City',
#      'city_id': 280,
#      'latitude': '40.7584111111',
#      'longitude': '-73.9882666667',
#      'zipcode': '10036',
#      'country_id': 216,
#      'locality_verbose': 'West 44th Street, Gramercy, New York City'},
#     'switch_to_order_menu': 0,
#     'cuisines': 'Italian, Pizza',
#     'average_cost_for_two': 40,
#     'price_range': 3,
#     'currency': '$',
#     'offers': [],
#     'opentable_support': 0,
#     'is_zomato_book_res': 0,
#     'mezzo_provider': 'OTHER',
#     'is_book_form_web_view': 0,
#     'book_form_web_view_url': '',
#     'book_again_url': '',
#     'thumb': 'https://b.zmtcdn.com/data/res_imagery/16769089_RESTAURANT_a7a23ba46bdbe76f7ffffc175679ede9_c.jpg?fit=around%7C200%3A200&crop=200%3A200%3B%2A%2C%2A',
#     'user_rating': {'aggregate_rating': '4.6',
#      'rating_text': 'Excellent',
#      'rating_color': '3F7E00',
#      'votes': '714',
#      'has_fake_reviews': 0},
#     'photos_url': 'https://www.zomato.com/new-york-city/johns-pizza-of-times-square-gramercy/photos?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1#tabtop',
#     'menu_url': 'https://www.zomato.com/new-york-city/johns-pizza-of-times-square-gramercy/menu?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1&openSwipeBox=menu&showMinimal=1#tabtop',
#     'featured_image': 'https://b.zmtcdn.com/data/res_imagery/16769089_RESTAURANT_a7a23ba46bdbe76f7ffffc175679ede9_c.jpg',
#     'has_online_delivery': 0,
#     'is_delivering_now': 0,
#     'has_fake_reviews': 0,
#     'include_bogo_offers': True,
#     'deeplink': 'zomato://restaurant/16769089',
#     'is_table_reservation_supported': 0,
#     'has_table_booking': 0,
#     'events_url': 'https://www.zomato.com/new-york-city/johns-pizza-of-times-square-gramercy/events#tabtop?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#     'establishment_types': []}},
#   {'restaurant': {'R': {'res_id': 16770626},
#     'apikey': '06e95084cb5d3426c57b51987827eb7d',
#     'id': '16770626',
#     'name': 'Le Bernardin',
#     'url': 'https://www.zomato.com/new-york-city/le-bernardin-gramercy?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#     'location': {'address': '155 W 51st Street, New York 10019',
#      'locality': 'Gramercy',
#      'city': 'New York City',
#      'city_id': 280,
#      'latitude': '40.7608027778',
#      'longitude': '-73.9819194444',
#      'zipcode': '10019',
#      'country_id': 216,
#      'locality_verbose': 'Gramercy'},
#     'switch_to_order_menu': 0,
#     'cuisines': 'French, Seafood',
#     'average_cost_for_two': 500,
#     'price_range': 4,
#     'currency': '$',
#     'offers': [],
#     'opentable_support': 0,
#     'is_zomato_book_res': 0,
#     'mezzo_provider': 'OTHER',
#     'is_book_form_web_view': 0,
#     'book_form_web_view_url': '',
#     'book_again_url': '',
#     'thumb': 'https://b.zmtcdn.com/data/pictures/6/16770626/a88c9e45fa431feacbd60f19a494165e.jpg?fit=around%7C200%3A200&crop=200%3A200%3B%2A%2C%2A',
#     'user_rating': {'aggregate_rating': '4.8',
#      'rating_text': 'Excellent',
#      'rating_color': '3F7E00',
#      'votes': '690',
#      'has_fake_reviews': 0},
#     'photos_url': 'https://www.zomato.com/new-york-city/le-bernardin-gramercy/photos?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1#tabtop',
#     'menu_url': 'https://www.zomato.com/new-york-city/le-bernardin-gramercy/menu?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1&openSwipeBox=menu&showMinimal=1#tabtop',
#     'featured_image': 'https://b.zmtcdn.com/data/pictures/6/16770626/a88c9e45fa431feacbd60f19a494165e.jpg',
#     'has_online_delivery': 0,
#     'is_delivering_now': 0,
#     'has_fake_reviews': 0,
#     'include_bogo_offers': True,
#     'deeplink': 'zomato://restaurant/16770626',
#     'is_table_reservation_supported': 0,
#     'has_table_booking': 0,
#     'events_url': 'https://www.zomato.com/new-york-city/le-bernardin-gramercy/events#tabtop?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#     'establishment_types': []}},
#   {'restaurant': {'R': {'res_id': 16781875},
#     'apikey': '06e95084cb5d3426c57b51987827eb7d',
#     'id': '16781875',
#     'name': 'Ippudo',
#     'url': 'https://www.zomato.com/new-york-city/ippudo-east-village?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#     'location': {'address': '65 4th Avenue, New York 10003',
#      'locality': 'East Village',
#      'city': 'New York City',
#      'city_id': 280,
#      'latitude': '40.7307361111',
#      'longitude': '-73.9906833333',
#      'zipcode': '10003',
#      'country_id': 216,
#      'locality_verbose': 'East Village'},
#     'switch_to_order_menu': 0,
#     'cuisines': 'Ramen',
#     'average_cost_for_two': 40,
#     'price_range': 3,
#     'currency': '$',
#     'offers': [],
#     'opentable_support': 0,
#     'is_zomato_book_res': 0,
#     'mezzo_provider': 'OTHER',
#     'is_book_form_web_view': 0,
#     'book_form_web_view_url': '',
#     'book_again_url': '',
#     'thumb': 'https://b.zmtcdn.com/data/pictures/5/16781875/1a72663426d6e780f6363b6b7da6d48b.png?fit=around%7C200%3A200&crop=200%3A200%3B%2A%2C%2A',
#     'user_rating': {'aggregate_rating': '4.9',
#      'rating_text': 'Excellent',
#      'rating_color': '3F7E00',
#      'votes': '921',
#      'has_fake_reviews': 0},
#     'photos_url': 'https://www.zomato.com/new-york-city/ippudo-east-village/photos?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1#tabtop',
#     'menu_url': 'https://www.zomato.com/new-york-city/ippudo-east-village/menu?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1&openSwipeBox=menu&showMinimal=1#tabtop',
#     'featured_image': 'https://b.zmtcdn.com/data/pictures/5/16781875/1a72663426d6e780f6363b6b7da6d48b.png?output-format=webp',
#     'has_online_delivery': 0,
#     'is_delivering_now': 0,
#     'has_fake_reviews': 0,
#     'include_bogo_offers': True,
#     'deeplink': 'zomato://restaurant/16781875',
#     'is_table_reservation_supported': 0,
#     'has_table_booking': 0,
#     'events_url': 'https://www.zomato.com/new-york-city/ippudo-east-village/events#tabtop?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#     'establishment_types': []}},
#   {'restaurant': {'R': {'res_id': 16765367},
#     'apikey': '06e95084cb5d3426c57b51987827eb7d',
#     'id': '16765367',
#     'name': 'Eleven Madison Park',
#     'url': 'https://www.zomato.com/new-york-city/eleven-madison-park-gramercy-flatiron?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#     'location': {'address': '11 Madison Avenue, New York 10010',
#      'locality': 'Gramercy-Flatiron',
#      'city': 'New York City',
#      'city_id': 280,
#      'latitude': '40.7415086000',
#      'longitude': '-73.9866285000',
#      'zipcode': '10010',
#      'country_id': 216,
#      'locality_verbose': 'Gramercy-Flatiron'},
#     'switch_to_order_menu': 0,
#     'cuisines': 'New American, French',
#     'average_cost_for_two': 650,
#     'price_range': 4,
#     'currency': '$',
#     'offers': [],
#     'opentable_support': 0,
#     'is_zomato_book_res': 0,
#     'mezzo_provider': 'OTHER',
#     'is_book_form_web_view': 0,
#     'book_form_web_view_url': '',
#     'book_again_url': '',
#     'thumb': 'https://b.zmtcdn.com/data/pictures/7/16765367/c118f3b0f7676bd605ae0355fc784b70.png?fit=around%7C200%3A200&crop=200%3A200%3B%2A%2C%2A',
#     'user_rating': {'aggregate_rating': '4.8',
#      'rating_text': 'Excellent',
#      'rating_color': '3F7E00',
#      'votes': '550',
#      'has_fake_reviews': 0},
#     'photos_url': 'https://www.zomato.com/new-york-city/eleven-madison-park-gramercy-flatiron/photos?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1#tabtop',
#     'menu_url': 'https://www.zomato.com/new-york-city/eleven-madison-park-gramercy-flatiron/menu?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1&openSwipeBox=menu&showMinimal=1#tabtop',
#     'featured_image': 'https://b.zmtcdn.com/data/pictures/7/16765367/c118f3b0f7676bd605ae0355fc784b70.png',
#     'has_online_delivery': 0,
#     'is_delivering_now': 0,
#     'has_fake_reviews': 0,
#     'include_bogo_offers': True,
#     'deeplink': 'zomato://restaurant/16765367',
#     'is_table_reservation_supported': 0,
#     'has_table_booking': 0,
#     'events_url': 'https://www.zomato.com/new-york-city/eleven-madison-park-gramercy-flatiron/events#tabtop?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#     'establishment_types': []}},
#   {'restaurant': {'R': {'res_id': 16761344},
#     'apikey': '06e95084cb5d3426c57b51987827eb7d',
#     'id': '16761344',
#     'name': 'Buddakan',
#     'url': 'https://www.zomato.com/new-york-city/buddakan-greenwich-village?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#     'location': {'address': '75 9th Avenue 10011',
#      'locality': '9th Avenue, Greenwich Village',
#      'city': 'New York City',
#      'city_id': 280,
#      'latitude': '40.7422762672',
#      'longitude': '-74.0048000962',
#      'zipcode': '10011',
#      'country_id': 216,
#      'locality_verbose': '9th Avenue, Greenwich Village, New York City'},
#     'switch_to_order_menu': 0,
#     'cuisines': 'Chinese, Fusion, Asian',
#     'average_cost_for_two': 130,
#     'price_range': 4,
#     'currency': '$',
#     'offers': [],
#     'opentable_support': 0,
#     'is_zomato_book_res': 0,
#     'mezzo_provider': 'OTHER',
#     'is_book_form_web_view': 0,
#     'book_form_web_view_url': '',
#     'book_again_url': '',
#     'thumb': 'https://b.zmtcdn.com/data/pictures/4/16761344/5535198640b49778b948e916d392ebb8.jpg?fit=around%7C200%3A200&crop=200%3A200%3B%2A%2C%2A',
#     'user_rating': {'aggregate_rating': '4.9',
#      'rating_text': 'Excellent',
#      'rating_color': '3F7E00',
#      'votes': '906',
#      'has_fake_reviews': 0},
#     'photos_url': 'https://www.zomato.com/new-york-city/buddakan-greenwich-village/photos?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1#tabtop',
#     'menu_url': 'https://www.zomato.com/new-york-city/buddakan-greenwich-village/menu?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1&openSwipeBox=menu&showMinimal=1#tabtop',
#     'featured_image': 'https://b.zmtcdn.com/data/pictures/4/16761344/5535198640b49778b948e916d392ebb8.jpg',
#     'has_online_delivery': 0,
#     'is_delivering_now': 0,
#     'has_fake_reviews': 0,
#     'include_bogo_offers': True,
#     'deeplink': 'zomato://restaurant/16761344',
#     'is_table_reservation_supported': 0,
#     'has_table_booking': 0,
#     'events_url': 'https://www.zomato.com/new-york-city/buddakan-greenwich-village/events#tabtop?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#     'establishment_types': []}},
#   {'restaurant': {'R': {'res_id': 16775526},
#     'apikey': '06e95084cb5d3426c57b51987827eb7d',
#     'id': '16775526',
#     'name': 'Pommes Frites',
#     'url': 'https://www.zomato.com/new-york-city/pommes-frites-1-greenwich-village?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#     'location': {'address': '128 Macdougal Street, New York 10012',
#      'locality': 'Greenwich Village',
#      'city': 'New York City',
#      'city_id': 280,
#      'latitude': '40.7300310000',
#      'longitude': '-74.0001620000',
#      'zipcode': '10012',
#      'country_id': 216,
#      'locality_verbose': 'Greenwich Village'},
#     'switch_to_order_menu': 0,
#     'cuisines': 'European, Belgian',
#     'average_cost_for_two': 35,
#     'price_range': 2,
#     'currency': '$',
#     'offers': [],
#     'opentable_support': 0,
#     'is_zomato_book_res': 0,
#     'mezzo_provider': 'OTHER',
#     'is_book_form_web_view': 0,
#     'book_form_web_view_url': '',
#     'book_again_url': '',
#     'thumb': '',
#     'user_rating': {'aggregate_rating': '4.8',
#      'rating_text': 'Excellent',
#      'rating_color': '3F7E00',
#      'votes': '710',
#      'has_fake_reviews': 0},
#     'photos_url': 'https://www.zomato.com/new-york-city/pommes-frites-1-greenwich-village/photos?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1#tabtop',
#     'menu_url': 'https://www.zomato.com/new-york-city/pommes-frites-1-greenwich-village/menu?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1&openSwipeBox=menu&showMinimal=1#tabtop',
#     'featured_image': '',
#     'has_online_delivery': 0,
#     'is_delivering_now': 0,
#     'has_fake_reviews': 0,
#     'include_bogo_offers': True,
#     'deeplink': 'zomato://restaurant/16775526',
#     'is_table_reservation_supported': 0,
#     'has_table_booking': 0,
#     'events_url': 'https://www.zomato.com/new-york-city/pommes-frites-1-greenwich-village/events#tabtop?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#     'establishment_types': []}},
#   {'restaurant': {'R': {'res_id': 16776730},
#     'apikey': '06e95084cb5d3426c57b51987827eb7d',
#     'id': '16776730',
#     'name': 'Russ & Daughters',
#     'url': 'https://www.zomato.com/new-york-city/russ-daughters-lower-east-side?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#     'location': {'address': '179 E Houston Street, New York 10002',
#      'locality': 'Lower East Side',
#      'city': 'New York City',
#      'city_id': 280,
#      'latitude': '40.7227361111',
#      'longitude': '-73.9882361111',
#      'zipcode': '10002',
#      'country_id': 216,
#      'locality_verbose': 'Lower East Side'},
#     'switch_to_order_menu': 0,
#     'cuisines': 'Seafood, Bagels',
#     'average_cost_for_two': 25,
#     'price_range': 2,
#     'currency': '$',
#     'offers': [],
#     'opentable_support': 0,
#     'is_zomato_book_res': 0,
#     'mezzo_provider': 'OTHER',
#     'is_book_form_web_view': 0,
#     'book_form_web_view_url': '',
#     'book_again_url': '',
#     'thumb': 'https://b.zmtcdn.com/data/pictures/0/16776730/49e617fc653ad30851526dfefc8cef86.jpg?fit=around%7C200%3A200&crop=200%3A200%3B%2A%2C%2A',
#     'user_rating': {'aggregate_rating': '4.8',
#      'rating_text': 'Excellent',
#      'rating_color': '3F7E00',
#      'votes': '253',
#      'has_fake_reviews': 0},
#     'photos_url': 'https://www.zomato.com/new-york-city/russ-daughters-lower-east-side/photos?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1#tabtop',
#     'menu_url': 'https://www.zomato.com/new-york-city/russ-daughters-lower-east-side/menu?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1&openSwipeBox=menu&showMinimal=1#tabtop',
#     'featured_image': 'https://b.zmtcdn.com/data/pictures/0/16776730/49e617fc653ad30851526dfefc8cef86.jpg',
#     'has_online_delivery': 0,
#     'is_delivering_now': 0,
#     'has_fake_reviews': 0,
#     'include_bogo_offers': True,
#     'deeplink': 'zomato://restaurant/16776730',
#     'is_table_reservation_supported': 0,
#     'has_table_booking': 0,
#     'events_url': 'https://www.zomato.com/new-york-city/russ-daughters-lower-east-side/events#tabtop?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#     'establishment_types': []}},
#   {'restaurant': {'R': {'res_id': 16777384},
#     'apikey': '06e95084cb5d3426c57b51987827eb7d',
#     'id': '16777384',
#     'name': 'Shake Shack',
#     'url': 'https://www.zomato.com/new-york-city/shake-shack-gramercy-flatiron?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#     'location': {'address': 'Madison Square Park, 23rd & Madison, New York 10010',
#      'locality': 'Gramercy-Flatiron',
#      'city': 'New York City',
#      'city_id': 280,
#      'latitude': '40.7408681000',
#      'longitude': '-73.9879841000',
#      'zipcode': '10010',
#      'country_id': 216,
#      'locality_verbose': 'Gramercy-Flatiron'},
#     'switch_to_order_menu': 0,
#     'cuisines': 'American, Burger',
#     'average_cost_for_two': 30,
#     'price_range': 2,
#     'currency': '$',
#     'offers': [],
#     'opentable_support': 0,
#     'is_zomato_book_res': 0,
#     'mezzo_provider': 'OTHER',
#     'is_book_form_web_view': 0,
#     'book_form_web_view_url': '',
#     'book_again_url': '',
#     'thumb': 'https://b.zmtcdn.com/data/pictures/4/16777384/2a989275f117f6bf1f63919c66cbc2cc.jpg?fit=around%7C200%3A200&crop=200%3A200%3B%2A%2C%2A',
#     'user_rating': {'aggregate_rating': '4.9',
#      'rating_text': 'Excellent',
#      'rating_color': '3F7E00',
#      'votes': '1634',
#      'has_fake_reviews': 0},
#     'photos_url': 'https://www.zomato.com/new-york-city/shake-shack-gramercy-flatiron/photos?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1#tabtop',
#     'menu_url': 'https://www.zomato.com/new-york-city/shake-shack-gramercy-flatiron/menu?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1&openSwipeBox=menu&showMinimal=1#tabtop',
#     'featured_image': 'https://b.zmtcdn.com/data/pictures/4/16777384/2a989275f117f6bf1f63919c66cbc2cc.jpg',
#     'has_online_delivery': 0,
#     'is_delivering_now': 0,
#     'has_fake_reviews': 0,
#     'include_bogo_offers': True,
#     'deeplink': 'zomato://restaurant/16777384',
#     'is_table_reservation_supported': 0,
#     'has_table_booking': 0,
#     'events_url': 'https://www.zomato.com/new-york-city/shake-shack-gramercy-flatiron/events#tabtop?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#     'establishment_types': []}},
#   {'restaurant': {'R': {'res_id': 16761868},
#     'apikey': '06e95084cb5d3426c57b51987827eb7d',
#     'id': '16761868',
#     'name': 'Cafeteria',
#     'url': 'https://www.zomato.com/new-york-city/cafeteria-chelsea-manhattan?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#     'location': {'address': '119 7th Avenue 10011',
#      'locality': 'Chelsea, Manhattan',
#      'city': 'New York City',
#      'city_id': 280,
#      'latitude': '40.7407100000',
#      'longitude': '-73.9980000000',
#      'zipcode': '10011',
#      'country_id': 216,
#      'locality_verbose': 'Chelsea, Manhattan'},
#     'switch_to_order_menu': 0,
#     'cuisines': 'American',
#     'average_cost_for_two': 75,
#     'price_range': 4,
#     'currency': '$',
#     'offers': [],
#     'opentable_support': 0,
#     'is_zomato_book_res': 0,
#     'mezzo_provider': 'OTHER',
#     'is_book_form_web_view': 0,
#     'book_form_web_view_url': '',
#     'book_again_url': '',
#     'thumb': 'https://b.zmtcdn.com/data/pictures/chains/8/16761868/bd779e8a55d1e38bf489a4b373099cf1.jpg?fit=around%7C200%3A200&crop=200%3A200%3B%2A%2C%2A',
#     'user_rating': {'aggregate_rating': '4.4',
#      'rating_text': 'Very Good',
#      'rating_color': '5BA829',
#      'votes': '634',
#      'has_fake_reviews': 0},
#     'photos_url': 'https://www.zomato.com/new-york-city/cafeteria-chelsea-manhattan/photos?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1#tabtop',
#     'menu_url': 'https://www.zomato.com/new-york-city/cafeteria-chelsea-manhattan/menu?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1&openSwipeBox=menu&showMinimal=1#tabtop',
#     'featured_image': 'https://b.zmtcdn.com/data/pictures/chains/8/16761868/bd779e8a55d1e38bf489a4b373099cf1.jpg',
#     'has_online_delivery': 0,
#     'is_delivering_now': 0,
#     'has_fake_reviews': 0,
#     'include_bogo_offers': True,
#     'deeplink': 'zomato://restaurant/16761868',
#     'is_table_reservation_supported': 0,
#     'has_table_booking': 0,
#     'events_url': 'https://www.zomato.com/new-york-city/cafeteria-chelsea-manhattan/events#tabtop?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#     'establishment_types': []}},
#   {'restaurant': {'R': {'res_id': 16767139},
#     'apikey': '06e95084cb5d3426c57b51987827eb7d',
#     'id': '16767139',
#     'name': 'Gramercy Tavern',
#     'url': 'https://www.zomato.com/new-york-city/gramercy-tavern-gramercy-flatiron?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#     'location': {'address': '42 E 20th Street 10003',
#      'locality': 'East 20th Street, Gramercy-Flatiron',
#      'city': 'New York City',
#      'city_id': 280,
#      'latitude': '40.7387166667',
#      'longitude': '-73.9883888889',
#      'zipcode': '10003',
#      'country_id': 216,
#      'locality_verbose': 'East 20th Street, Gramercy-Flatiron, New York City'},
#     'switch_to_order_menu': 0,
#     'cuisines': 'American',
#     'average_cost_for_two': 200,
#     'price_range': 4,
#     'currency': '$',
#     'offers': [],
#     'opentable_support': 0,
#     'is_zomato_book_res': 0,
#     'mezzo_provider': 'OTHER',
#     'is_book_form_web_view': 0,
#     'book_form_web_view_url': '',
#     'book_again_url': '',
#     'thumb': 'https://b.zmtcdn.com/data/pictures/9/16767139/8e3fae144133ba709852d6eec7280397.jpg?fit=around%7C200%3A200&crop=200%3A200%3B%2A%2C%2A',
#     'user_rating': {'aggregate_rating': '4.5',
#      'rating_text': 'Excellent',
#      'rating_color': '3F7E00',
#      'votes': '959',
#      'has_fake_reviews': 0},
#     'photos_url': 'https://www.zomato.com/new-york-city/gramercy-tavern-gramercy-flatiron/photos?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1#tabtop',
#     'menu_url': 'https://www.zomato.com/new-york-city/gramercy-tavern-gramercy-flatiron/menu?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1&openSwipeBox=menu&showMinimal=1#tabtop',
#     'featured_image': 'https://b.zmtcdn.com/data/pictures/9/16767139/8e3fae144133ba709852d6eec7280397.jpg',
#     'has_online_delivery': 0,
#     'is_delivering_now': 0,
#     'has_fake_reviews': 0,
#     'include_bogo_offers': True,
#     'deeplink': 'zomato://restaurant/16767139',
#     'is_table_reservation_supported': 0,
#     'has_table_booking': 0,
#     'events_url': 'https://www.zomato.com/new-york-city/gramercy-tavern-gramercy-flatiron/events#tabtop?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#     'establishment_types': []}},
#   {'restaurant': {'R': {'res_id': 16761402},
#     'apikey': '06e95084cb5d3426c57b51987827eb7d',
#     'id': '16761402',
#     'name': 'Burger Joint',
#     'url': 'https://www.zomato.com/new-york-city/burger-joint-midtown?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#     'location': {'address': '119 West 56th Street 10019',
#      'locality': 'Midtown',
#      'city': 'New York City',
#      'city_id': 280,
#      'latitude': '40.7639500000',
#      'longitude': '-73.9781800000',
#      'zipcode': '10019',
#      'country_id': 216,
#      'locality_verbose': 'Midtown'},
#     'switch_to_order_menu': 0,
#     'cuisines': 'Burger',
#     'average_cost_for_two': 25,
#     'price_range': 2,
#     'currency': '$',
#     'offers': [],
#     'opentable_support': 0,
#     'is_zomato_book_res': 0,
#     'mezzo_provider': 'OTHER',
#     'is_book_form_web_view': 0,
#     'book_form_web_view_url': '',
#     'book_again_url': '',
#     'thumb': 'https://b.zmtcdn.com/data/pictures/chains/2/16761402/beda9e63e3230d51c78f589d45e372cf.jpg?fit=around%7C200%3A200&crop=200%3A200%3B%2A%2C%2A',
#     'user_rating': {'aggregate_rating': '4.8',
#      'rating_text': 'Excellent',
#      'rating_color': '3F7E00',
#      'votes': '870',
#      'has_fake_reviews': 0},
#     'photos_url': 'https://www.zomato.com/new-york-city/burger-joint-midtown/photos?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1#tabtop',
#     'menu_url': 'https://www.zomato.com/new-york-city/burger-joint-midtown/menu?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1&openSwipeBox=menu&showMinimal=1#tabtop',
#     'featured_image': 'https://b.zmtcdn.com/data/pictures/chains/2/16761402/beda9e63e3230d51c78f589d45e372cf.jpg',
#     'has_online_delivery': 0,
#     'is_delivering_now': 0,
#     'has_fake_reviews': 0,
#     'include_bogo_offers': True,
#     'deeplink': 'zomato://restaurant/16761402',
#     'is_table_reservation_supported': 0,
#     'has_table_booking': 0,
#     'events_url': 'https://www.zomato.com/new-york-city/burger-joint-midtown/events#tabtop?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#     'establishment_types': []}}]}
