# %%
# pip install jsonmerge - install this package if the code won't run for you

# %%
import requests
from jsonmerge import merge
from pprint import pprint
import pandas as pd
from pandas.io.json import json_normalize
import json

# %%
Key = '06e95084cb5d3426c57b51987827eb7d'
url = "https://developers.zomato.com/api/v2.1/"

headers= {
    "user-key":Key,
    "Accept": "application/json" 
}


params= {
    "category": 3,
    "entity_id": 280,
    "entity_type": "city",
}

# search
results = requests.get(url=url+"search?",headers=headers,params=params)

# %%
# categories
results = requests.get(url=url+"categories?",headers=headers)

# %%
results.json()
# Out:
# {'categories': [{'categories': {'id': 1, 'name': 'Delivery'}},
#   {'categories': {'id': 2, 'name': 'Dine-out'}},
#   {'categories': {'id': 3, 'name': 'Nightlife'}},
#   {'categories': {'id': 4, 'name': 'Catching-up'}},
#   {'categories': {'id': 5, 'name': 'Takeaway'}},
#   {'categories': {'id': 6, 'name': 'Cafes'}},
#   {'categories': {'id': 7, 'name': 'Daily Menus'}},
#   {'categories': {'id': 8, 'name': 'Breakfast'}},
#   {'categories': {'id': 9, 'name': 'Lunch'}},
#   {'categories': {'id': 10, 'name': 'Dinner'}},
#   {'categories': {'id': 11, 'name': 'Pubs & Bars'}},
#   {'categories': {'id': 13, 'name': 'Pocket Friendly Delivery'}},
#   {'categories': {'id': 14, 'name': 'Clubs & Lounges'}}]}

# %% [markdown]
# ### Category 9 - Lunch results

# %%
# First 20 set of results
headers= {
    "user-key":Key,
    "Accept": "application/json" 
}
params= {
    "category": 9,
    "entity_id": 280,
    "entity_type": "city",
    "start": 0,
    "count":20
}

# search
lunch_results = requests.get(url=url+"search?",headers=headers,params=params)

####################################################################################

# Second 20 set of reults
params2= {
    "category": 9,
    "entity_id": 280,
    "entity_type": "city",
    "start": 20,
    "count":20
}

# search
lunch_results2 = requests.get(url=url+"search?",headers=headers,params=params2)

####################################################################################

# Third 20 set of reults
params2= {
    "category": 9,
    "entity_id": 280,
    "entity_type": "city",
    "start": 40,
    "count":20
}

# search
lunch_results3 = requests.get(url=url+"search?",headers=headers,params=params2)

####################################################################################

# Fourth 20 set of reults
params2= {
    "category": 9,
    "entity_id": 280,
    "entity_type": "city",
    "start": 60,
    "count":20
}

# search
lunch_results4 = requests.get(url=url+"search?",headers=headers,params=params2)

####################################################################################

# Fifth 20 set of reults
params2= {
    "category": 9,
    "entity_id": 280,
    "entity_type": "city",
    "start": 80,
    "count":20
}

# search
lunch_results5 = requests.get(url=url+"search?",headers=headers,params=params2)

####################################################################################

# Sixth 20 set of reults
params2= {
    "category": 9,
    "entity_id": 280,
    "entity_type": "city",
    "start": 100,
    "count":20
}

# search
lunch_results6 = requests.get(url=url+"search?",headers=headers,params=params2)

# %%
merge_1 = merge(lunch_results, lunch_results2)
merge_2 = merge(merge_1, lunch_results3)
merge_3 = merge(merge_2, lunch_results4)
merge_4 = merge(merge_3, lunch_results5)
# all_lunch = merge(merge_4, lunch_results6)
merge_4.json()
# Out:
# {'results_found': 37279,
#  'results_start': 80,
#  'results_shown': 20,
#  'restaurants': [{'restaurant': {'R': {'res_id': 16781746},
#     'apikey': '06e95084cb5d3426c57b51987827eb7d',
#     'id': '16781746',
#     'name': 'Fette Sau',
#     'url': 'https://www.zomato.com/new-york-city/fette-sau-north-williamsburg-north-side?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#     'location': {'address': '354 Metropolitan Avenue 11211',
#      'locality': 'North Williamsburg - North Side',
#      'city': 'New York City',
#      'city_id': 280,
#      'latitude': '40.7140300000',
#      'longitude': '-73.9567700000',
#      'zipcode': '11211',
#      'country_id': 216,
#      'locality_verbose': 'North Williamsburg - North Side'},
#     'switch_to_order_menu': 0,
#     'cuisines': 'American, BBQ',
#     'average_cost_for_two': 75,
#     'price_range': 4,
#     'currency': '$',
#     'offers': [],
#     'opentable_support': 0,
#     'is_zomato_book_res': 0,
# ...

# %%
result = json_normalize(lunch_results, 'restaurants', ['name', 'location', 'locality', 'city', 'latitude', 'longitude', 
                                                 'zipcode', 'cuisines', 'rating_text', 'menu_url'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-42-ee8cee34af20> in <module>
#       1 result = json_normalize(merge_4, 'restaurants', ['name', 'location', 'locality', 'city', 'latitude', 'longitude',
# ----> 2                                                  'zipcode', 'cuisines', 'rating_text', 'menu_url'])
#
# ~\Anaconda3\lib\site-packages\pandas\io\json\normalize.py in json_normalize(data, record_path, meta, meta_prefix, record_prefix, errors, sep)
#     260                 records.extend(recs)
#     261
# --> 262     _recursive_extract(data, record_path, {}, level=0)
#     263
#     264     result = DataFrame(records)
#
# ~\Anaconda3\lib\site-packages\pandas\io\json\normalize.py in _recursive_extract(data, path, seen_meta, level)
#     236         else:
#     237             for obj in data:
# --> 238                 recs = _pull_field(obj, path[0])
# ...

# %%
j = lunch_results.json()
j
# df = pd.DataFrame.from_dict(j)
# df.head()
# Out:
# {'results_found': 37279,
#  'results_start': 0,
#  'results_shown': 20,
#  'restaurants': [{'restaurant': {'R': {'res_id': 16767332},
#     'apikey': '06e95084cb5d3426c57b51987827eb7d',
#     'id': '16767332',
#     'name': "Grimaldi's Pizzeria",
#     'url': 'https://www.zomato.com/new-york-city/grimaldis-pizzeria-dumbo?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#     'location': {'address': '1 Front Street, Brooklyn 11201',
#      'locality': 'Front Street, DUMBO',
#      'city': 'New York City',
#      'city_id': 280,
#      'latitude': '40.7025138889',
#      'longitude': '-73.9932722222',
#      'zipcode': '11201',
#      'country_id': 216,
#      'locality_verbose': 'Front Street, DUMBO, New York City'},
#     'switch_to_order_menu': 0,
#     'cuisines': 'Pizza, Italian',
#     'average_cost_for_two': 50,
#     'price_range': 3,
#     'currency': '$',
#     'offers': [],
#     'opentable_support': 0,
#     'is_zomato_book_res': 0,
# ...

# %% [markdown]
# ### Category 3 - Nightlife results

# %%
# First 20 set of results
headers= {
    "user-key":Key,
    "Accept": "application/json" 
}
params= {
    "category": 9,
    "entity_id": 280,
    "entity_type": "city",
    "start": 0,
    "count":20
}

# search
lunch_results = requests.get(url=url+"search?",headers=headers,params=params)

####################################################################################

# Second 20 set of reults
params2= {
    "category": 9,
    "entity_id": 280,
    "entity_type": "city",
    "start": 20,
    "count":20
}

# search
lunch_results2 = requests.get(url=url+"search?",headers=headers,params=params2)

####################################################################################

# Third 20 set of reults
params2= {
    "category": 9,
    "entity_id": 280,
    "entity_type": "city",
    "start": 40,
    "count":20
}

# search
lunch_results3 = requests.get(url=url+"search?",headers=headers,params=params2)

####################################################################################

# Fourth 20 set of reults
params2= {
    "category": 9,
    "entity_id": 280,
    "entity_type": "city",
    "start": 60,
    "count":20
}

# search
lunch_results4 = requests.get(url=url+"search?",headers=headers,params=params2)

####################################################################################

# Fifth 20 set of reults
params2= {
    "category": 9,
    "entity_id": 280,
    "entity_type": "city",
    "start": 80,
    "count":20
}

# search
lunch_results5 = requests.get(url=url+"search?",headers=headers,params=params2)

####################################################################################

# Sixth 20 set of reults
params2= {
    "category": 9,
    "entity_id": 280,
    "entity_type": "city",
    "start": 100,
    "count":20
}

# search
lunch_results6 = requests.get(url=url+"search?",headers=headers,params=params2)

# %%
headers= {
    "user-key":Key,
    "Accept": "application/json" 
}
params= {
    "category": 2,
    "entity_id": 280,
    "entity_type": "city",
}

# search
dine_results = requests.get(url=url+"search?",headers=headers,params=params)
